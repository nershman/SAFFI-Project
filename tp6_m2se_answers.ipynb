# %% [markdown]
# # Session - Web Usage Mining

# %% [markdown]
# We first import the package will will manipulate in this work.

# %%
import pandas as pd
import datetime
import sys

# %% [markdown]
# ## Data preprocessing
#
# In this secrtion, we are manipulating a sample of a real web access log file (`web_access.log`). The dataset description can be found there <http://ita.ee.lbl.gov/html/contrib/ClarkNet-HTTP.html>. As usual, real data have to be preprocessed.

# %% [markdown]
# We start by loading the data and storing them into a pandas dataframe. For this, use the `read_table` pandas function and set properly the parameters. If you encounter difficulties for loading the data, that's perfectly normal. To see which lines are "malformed" you can use `error_bad_lines=False, warn_bad_lines=True` when loading the data. Once you have identified the problem, write a Python function to generate a correct file (named `web_access_correct.log`) from the malformed one. Once the function has been called, you can load the dataset into a Pandas dataframe.

# %%
df_dirty = pd.read_table("web_access.log", sep="\s+", quotechar='"', header=None, 
                         error_bad_lines=False, warn_bad_lines=True)
# Out:
# b'Skipping line 13106: expected 8 fields, saw 9\nSkipping line 19564: expected 8 fields, saw 9\nSkipping line 27058: expected 8 fields, saw 9\nSkipping line 29291: expected 8 fields, saw 9\nSkipping line 55677: expected 8 fields, saw 9\nSkipping line 60366: expected 8 fields, saw 9\n'
# b'Skipping line 73882: expected 8 fields, saw 9\nSkipping line 74033: expected 8 fields, saw 9\nSkipping line 74335: expected 8 fields, saw 9\nSkipping line 76367: expected 8 fields, saw 9\nSkipping line 76760: expected 8 fields, saw 9\n'

# %%
with open("web_access.log", "r") as fin : 
    with open("web_access_correct.log", "w") as fout : 
        for l in fin : 
            fout.write(l.replace('" HTTP',' HTTP'))

# %%
df = pd.read_table("web_access_correct.log", sep="\s+", quotechar='"', 
                   header=None, error_bad_lines=False, warn_bad_lines=True)

# %%
df
# Out:
#                                             0  1  2                      3  \
# 0                              204.249.225.59  -  -  [28/Aug/1995:00:00:34
# 1                         access9.accsyst.com  -  -  [28/Aug/1995:00:00:35
# 2                         access9.accsyst.com  -  -  [28/Aug/1995:00:00:35
# 3                               world.std.com  -  -  [28/Aug/1995:00:00:36
# 4                            cssu24.cs.ust.hk  -  -  [28/Aug/1995:00:00:36
# 5                             er6.rutgers.edu  -  -  [28/Aug/1995:00:00:37
# 6                 cyclom1-1-6.intersource.com  -  -  [28/Aug/1995:00:00:37
# 7              d24-1.cpe.Brisbane.aone.net.au  -  -  [28/Aug/1995:00:00:38
# 8                               world.std.com  -  -  [28/Aug/1995:00:00:38
# 9                               world.std.com  -  -  [28/Aug/1995:00:00:38
# 10                              world.std.com  -  -  [28/Aug/1995:00:00:38
# 11                           cssu24.cs.ust.hk  -  -  [28/Aug/1995:00:00:39
# 12             d24-1.cpe.Brisbane.aone.net.au  -  -  [28/Aug/1995:00:00:40
# 13                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:43
# 14                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:43
# 15                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:44
# 16                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:44
# 17                                ari.ari.net  -  -  [28/Aug/1995:00:00:45
# 18                              world.std.com  -  -  [28/Aug/1995:00:00:45
# 19                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:45
# 20                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:45
# 21                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:46
# 22                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:46
# 23                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:46
# 24                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:46
# 25                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:46
# 26                           cssu24.cs.ust.hk  -  -  [28/Aug/1995:00:00:46
# 27                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:48
# 28                      freenet3.scri.fsu.edu  -  -  [28/Aug/1995:00:00:48
# 29                         ppp19.glas.apc.org  -  -  [28/Aug/1995:00:00:48
# ...                                       ... .. ..                    ...
# 99970                           sgs.clark.net  -  -  [28/Aug/1995:12:41:55
# 99971                           141.192.47.25  -  -  [28/Aug/1995:12:41:55
# 99972                           sgs.clark.net  -  -  [28/Aug/1995:12:41:55
# 99973                     lspc41.nsls.bnl.gov  -  -  [28/Aug/1995:12:41:55
# 99974                 scarpent.iac.gatech.edu  -  -  [28/Aug/1995:12:41:56
# 99975                             146.9.7.243  -  -  [28/Aug/1995:12:41:56
# 99976                         hntp2.hinet.net  -  -  [28/Aug/1995:12:41:56
# 99977  hhh6.orgchemie.chemie.uni-tuebingen.de  -  -  [28/Aug/1995:12:41:56
# 99978                   oed.saclantc.nato.int  -  -  [28/Aug/1995:12:41:56
# 99979                    piweba4y.prodigy.com  -  -  [28/Aug/1995:12:41:56
# 99980                   PPP-PORT10.xyplex.com  -  -  [28/Aug/1995:12:41:56
# 99981                   oed.saclantc.nato.int  -  -  [28/Aug/1995:12:41:57
# 99982                       ppp13.cac.psu.edu  -  -  [28/Aug/1995:12:41:57
# 99983                       ppp13.cac.psu.edu  -  -  [28/Aug/1995:12:41:57
# 99984  hhh6.orgchemie.chemie.uni-tuebingen.de  -  -  [28/Aug/1995:12:41:57
# 99985                    piweba4y.prodigy.com  -  -  [28/Aug/1995:12:41:58
# 99986                 dd11-015.compuserve.com  -  -  [28/Aug/1995:12:41:58
# 99987                            147.160.8.12  -  -  [28/Aug/1995:12:41:58
# 99988                      crc3-fddi.cris.com  -  -  [28/Aug/1995:12:41:58
# 99989                    homer.scs.uottawa.ca  -  -  [28/Aug/1995:12:41:58
# 99990                     ppp-nyc-5-4.ios.com  -  -  [28/Aug/1995:12:41:58
# 99991                   oed.saclantc.nato.int  -  -  [28/Aug/1995:12:41:58
# 99992                            147.160.8.12  -  -  [28/Aug/1995:12:41:58
# 99993                            147.160.8.12  -  -  [28/Aug/1995:12:41:58
# 99994                       ppp13.cac.psu.edu  -  -  [28/Aug/1995:12:41:59
# 99995                       ppp13.cac.psu.edu  -  -  [28/Aug/1995:12:41:59
# 99996                             205.206.4.2  -  -  [28/Aug/1995:12:41:59
# 99997                     hnlp57.VERIFONE.COM  -  -  [28/Aug/1995:12:41:59
# 99998                       ppp13.cac.psu.edu  -  -  [28/Aug/1995:12:42:00
# 99999  hhh6.orgchemie.chemie.uni-tuebingen.de  -  -  [28/Aug/1995:12:42:00
#
#             4                                                  5    6       7
# 0      -0400]  GET /pub/rmharris/catalogs/dawsocat/intro.html...  200    3542
# 1      -0400]                GET /pub/robert/past99.gif HTTP/1.0  200    4993
# 2      -0400]                GET /pub/robert/curr99.gif HTTP/1.0  200    5836
# 3      -0400]    GET /pub/atomicbk/catalog/sleazbk.html HTTP/1.0  200   18338
# 4      -0400]                GET /pub/job/vk/view17.jpg HTTP/1.0  200    5944
# 5      -0400]               GET /pub/rjgula/network.htm HTTP/1.0  200    2017
# 6      -0400]                  GET /pub/k2/jeep/jxj.htm HTTP/1.0  200    3254
# 7      -0400]                GET /pub/eurocent/home.htm HTTP/1.0  200    2534
# 8      -0400]        GET /pub/atomicbk/catalog/home.gif HTTP/1.0  200     813
# 9      -0400]       GET /pub/atomicbk/catalog/logo2.gif HTTP/1.0  200   12871
# 10     -0400]     GET /pub/atomicbk/catalog/catalog.gif HTTP/1.0  200     693
# 11     -0400]                GET /pub/job/vk/view18.jpg HTTP/1.0  200    6578
# 12     -0400]               GET /pub/eurocent/tiny2.gif HTTP/1.0  200    1152
# 13     -0400]                            GET /atomicbk/ HTTP/1.0  304       -
# 14     -0400]                 GET /atomicbk/contest.gif HTTP/1.0  304       -
# 15     -0400]                  GET /atomicbk/artgal.gif HTTP/1.0  304       -
# 16     -0400]                   GET /atomicbk/email.gif HTTP/1.0  304       -
# 17     -0400]                                     GET / HTTP/1.0  200    1834
# 18     -0400]         GET /pub/atomicbk/catalog/new.gif HTTP/1.0  200     744
# 19     -0400]                   GET /atomicbk/promo.gif HTTP/1.0  304       -
# 20     -0400]                    GET /atomicbk/news.gif HTTP/1.0  304       -
# 21     -0400]                     GET /atomicbk/new.gif HTTP/1.0  304       -
# 22     -0400]                 GET /atomicbk/catalog.gif HTTP/1.0  304       -
# 23     -0400]                   GET /atomicbk/logo2.gif HTTP/1.0  304       -
# 24     -0400]                  GET /atomicbk/emboss.jpg HTTP/1.0  304       -
# 25     -0400]                  GET /atomicbk/direct.gif HTTP/1.0  304       -
# 26     -0400]                GET /pub/job/vk/v-line.gif HTTP/1.0  200    1254
# 27     -0400]                  GET /atomicbk/scotth.gif HTTP/1.0  200     790
# 28     -0400]               GET /pub/rjgula/network.htm HTTP/1.0  200    2017
# 29     -0400]                  GET /atomicbk/orders.gif HTTP/1.0  304       -
# ...       ...                                                ...  ...     ...
# 99970  -0400]                GET /pub/sgs/gifs/ubbg.gif HTTP/1.0  200    4218
# 99971  -0400]                GET /pub/job/vk/view19.jpg HTTP/1.0  200    3915
# 99972  -0400]             GET /pub/sgs/gifs/ublogob.gif HTTP/1.0  200    2570
# 99973  -0400]              GET /pub/job/vk/vk-ad-15.jpg HTTP/1.0  200   77093
# 99974  -0400]      GET /pub/warnock/archie_warnock.html HTTP/1.0  200    4827
# 99975  -0400]        GET /pub/k2/am4x44u/gifs/jjbg2.jpg HTTP/1.0  200  169367
# 99976  -0400]            GET /pub/mikebilt/kinkbear.jpg HTTP/1.0  404     325
# 99977  -0400]                GET /pub/job/vk/view04.jpg HTTP/1.0  200    4847
# 99978  -0400]          GET /pub/aztec/hans/hc43-03z.gif HTTP/1.0  200    5602
# 99979  -0400]        GET /pub/atomicbk/catalog/mini.gif HTTP/1.0  304       -
# 99980  -0400]                   GET /pub/job/vk/bam.gif HTTP/1.0  200    9076
# 99981  -0400]           GET /pub/aztec/hans/hctitle.gif HTTP/1.0  200   10579
# 99982  -0400]            GET /pub/mbrophy/pix/thing.jpg HTTP/1.0  304       -
# 99983  -0400]            GET /pub/mbrophy/pix/holly.jpg HTTP/1.0  304       -
# 99984  -0400]                GET /pub/job/vk/view05.jpg HTTP/1.0  200    5012
# 99985  -0400]       GET /pub/atomicbk/catalog/logo2.gif HTTP/1.0  304       -
# 99986  -0400]  GET /pub/ahasuer/heinlein/juan.rico.html HTTP/1.0  200     511
# 99987  -0400]            GET /pub/mileskb/boc/news.html HTTP/1.0  304       -
# 99988  -0400]              GET /pub/ashp/grafx/logo.jpg HTTP/1.0  200    5994
# 99989  -0400]         GET /pub/atomicbk/catalog/new.gif HTTP/1.0  200     744
# 99990  -0400]                 GET /printing/E-CARD.html HTTP/1.0  200    2046
# 99991  -0400]          GET /pub/aztec/hans/hc43-01z.gif HTTP/1.0  200   10642
# 99992  -0400]             GET /pub/mileskb/boc/home.gif HTTP/1.0  304       -
# 99993  -0400]             GET /pub/mileskb/boc/logo.gif HTTP/1.0  304       -
# 99994  -0400]           GET /pub/mbrophy/pix/review.jpg HTTP/1.0  304       -
# 99995  -0400]            GET /pub/mbrophy/pix/other.jpg HTTP/1.0  304       -
# 99996  -0400]       GET /pub/atomicbk/images/stereo.gif HTTP/1.0  404     335
# 99997  -0400]                         GET /pub/stc/www/ HTTP/1.0  200    1222
# 99998  -0400]            GET /pub/mbrophy/pix/about.jpg HTTP/1.0  304       -
# 99999  -0400]                GET /pub/job/vk/view06.jpg HTTP/1.0  200    6553
#
# [100000 rows x 8 columns]

# %% [markdown]
# At this point, we have data stored into a dataframe but there exists a couple of problem isn't it? Here is the list of issues you need to fix before starting to clean the data :
#   - Columns 1, 2, 4 and 7 are useless (with column 1 being the seconc column)
#   - Column 5 stores three distinct information (the HTTP method, the accessed resource and the HTTP protocol version used by the user). It is thus needed to split this column into three ones.
#   - Column 3 represents a datetime but is considered as a string. When we will perform the sessionization (splitting the dataset into sessions) we will use a time-oriented heuristic. It is thus suitable to convert this column from string to datetime.
#   - The name of the columns are not really explicit.

# %% [markdown]
# Let us first start by the most simple issue to solve: dropping columns. For this, use the function `drop` on the dataframe.

# %%
df_ = df.drop(columns=[1,2,7,4])
df_
# Out:
#                                             0                      3  \
# 0                              204.249.225.59  [28/Aug/1995:00:00:34
# 1                         access9.accsyst.com  [28/Aug/1995:00:00:35
# 2                         access9.accsyst.com  [28/Aug/1995:00:00:35
# 3                               world.std.com  [28/Aug/1995:00:00:36
# 4                            cssu24.cs.ust.hk  [28/Aug/1995:00:00:36
# 5                             er6.rutgers.edu  [28/Aug/1995:00:00:37
# 6                 cyclom1-1-6.intersource.com  [28/Aug/1995:00:00:37
# 7              d24-1.cpe.Brisbane.aone.net.au  [28/Aug/1995:00:00:38
# 8                               world.std.com  [28/Aug/1995:00:00:38
# 9                               world.std.com  [28/Aug/1995:00:00:38
# 10                              world.std.com  [28/Aug/1995:00:00:38
# 11                           cssu24.cs.ust.hk  [28/Aug/1995:00:00:39
# 12             d24-1.cpe.Brisbane.aone.net.au  [28/Aug/1995:00:00:40
# 13                         ppp19.glas.apc.org  [28/Aug/1995:00:00:43
# 14                         ppp19.glas.apc.org  [28/Aug/1995:00:00:43
# 15                         ppp19.glas.apc.org  [28/Aug/1995:00:00:44
# 16                         ppp19.glas.apc.org  [28/Aug/1995:00:00:44
# 17                                ari.ari.net  [28/Aug/1995:00:00:45
# 18                              world.std.com  [28/Aug/1995:00:00:45
# 19                         ppp19.glas.apc.org  [28/Aug/1995:00:00:45
# 20                         ppp19.glas.apc.org  [28/Aug/1995:00:00:45
# 21                         ppp19.glas.apc.org  [28/Aug/1995:00:00:46
# 22                         ppp19.glas.apc.org  [28/Aug/1995:00:00:46
# 23                         ppp19.glas.apc.org  [28/Aug/1995:00:00:46
# 24                         ppp19.glas.apc.org  [28/Aug/1995:00:00:46
# 25                         ppp19.glas.apc.org  [28/Aug/1995:00:00:46
# 26                           cssu24.cs.ust.hk  [28/Aug/1995:00:00:46
# 27                         ppp19.glas.apc.org  [28/Aug/1995:00:00:48
# 28                      freenet3.scri.fsu.edu  [28/Aug/1995:00:00:48
# 29                         ppp19.glas.apc.org  [28/Aug/1995:00:00:48
# ...                                       ...                    ...
# 99970                           sgs.clark.net  [28/Aug/1995:12:41:55
# 99971                           141.192.47.25  [28/Aug/1995:12:41:55
# 99972                           sgs.clark.net  [28/Aug/1995:12:41:55
# 99973                     lspc41.nsls.bnl.gov  [28/Aug/1995:12:41:55
# 99974                 scarpent.iac.gatech.edu  [28/Aug/1995:12:41:56
# 99975                             146.9.7.243  [28/Aug/1995:12:41:56
# 99976                         hntp2.hinet.net  [28/Aug/1995:12:41:56
# 99977  hhh6.orgchemie.chemie.uni-tuebingen.de  [28/Aug/1995:12:41:56
# 99978                   oed.saclantc.nato.int  [28/Aug/1995:12:41:56
# 99979                    piweba4y.prodigy.com  [28/Aug/1995:12:41:56
# 99980                   PPP-PORT10.xyplex.com  [28/Aug/1995:12:41:56
# 99981                   oed.saclantc.nato.int  [28/Aug/1995:12:41:57
# 99982                       ppp13.cac.psu.edu  [28/Aug/1995:12:41:57
# 99983                       ppp13.cac.psu.edu  [28/Aug/1995:12:41:57
# 99984  hhh6.orgchemie.chemie.uni-tuebingen.de  [28/Aug/1995:12:41:57
# 99985                    piweba4y.prodigy.com  [28/Aug/1995:12:41:58
# 99986                 dd11-015.compuserve.com  [28/Aug/1995:12:41:58
# 99987                            147.160.8.12  [28/Aug/1995:12:41:58
# 99988                      crc3-fddi.cris.com  [28/Aug/1995:12:41:58
# 99989                    homer.scs.uottawa.ca  [28/Aug/1995:12:41:58
# 99990                     ppp-nyc-5-4.ios.com  [28/Aug/1995:12:41:58
# 99991                   oed.saclantc.nato.int  [28/Aug/1995:12:41:58
# 99992                            147.160.8.12  [28/Aug/1995:12:41:58
# 99993                            147.160.8.12  [28/Aug/1995:12:41:58
# 99994                       ppp13.cac.psu.edu  [28/Aug/1995:12:41:59
# 99995                       ppp13.cac.psu.edu  [28/Aug/1995:12:41:59
# 99996                             205.206.4.2  [28/Aug/1995:12:41:59
# 99997                     hnlp57.VERIFONE.COM  [28/Aug/1995:12:41:59
# 99998                       ppp13.cac.psu.edu  [28/Aug/1995:12:42:00
# 99999  hhh6.orgchemie.chemie.uni-tuebingen.de  [28/Aug/1995:12:42:00
#
#                                                        5    6
# 0      GET /pub/rmharris/catalogs/dawsocat/intro.html...  200
# 1                    GET /pub/robert/past99.gif HTTP/1.0  200
# 2                    GET /pub/robert/curr99.gif HTTP/1.0  200
# 3        GET /pub/atomicbk/catalog/sleazbk.html HTTP/1.0  200
# 4                    GET /pub/job/vk/view17.jpg HTTP/1.0  200
# 5                   GET /pub/rjgula/network.htm HTTP/1.0  200
# 6                      GET /pub/k2/jeep/jxj.htm HTTP/1.0  200
# 7                    GET /pub/eurocent/home.htm HTTP/1.0  200
# 8            GET /pub/atomicbk/catalog/home.gif HTTP/1.0  200
# 9           GET /pub/atomicbk/catalog/logo2.gif HTTP/1.0  200
# 10        GET /pub/atomicbk/catalog/catalog.gif HTTP/1.0  200
# 11                   GET /pub/job/vk/view18.jpg HTTP/1.0  200
# 12                  GET /pub/eurocent/tiny2.gif HTTP/1.0  200
# 13                               GET /atomicbk/ HTTP/1.0  304
# 14                    GET /atomicbk/contest.gif HTTP/1.0  304
# 15                     GET /atomicbk/artgal.gif HTTP/1.0  304
# 16                      GET /atomicbk/email.gif HTTP/1.0  304
# 17                                        GET / HTTP/1.0  200
# 18            GET /pub/atomicbk/catalog/new.gif HTTP/1.0  200
# 19                      GET /atomicbk/promo.gif HTTP/1.0  304
# 20                       GET /atomicbk/news.gif HTTP/1.0  304
# 21                        GET /atomicbk/new.gif HTTP/1.0  304
# 22                    GET /atomicbk/catalog.gif HTTP/1.0  304
# 23                      GET /atomicbk/logo2.gif HTTP/1.0  304
# 24                     GET /atomicbk/emboss.jpg HTTP/1.0  304
# 25                     GET /atomicbk/direct.gif HTTP/1.0  304
# 26                   GET /pub/job/vk/v-line.gif HTTP/1.0  200
# 27                     GET /atomicbk/scotth.gif HTTP/1.0  200
# 28                  GET /pub/rjgula/network.htm HTTP/1.0  200
# 29                     GET /atomicbk/orders.gif HTTP/1.0  304
# ...                                                  ...  ...
# 99970                GET /pub/sgs/gifs/ubbg.gif HTTP/1.0  200
# 99971                GET /pub/job/vk/view19.jpg HTTP/1.0  200
# 99972             GET /pub/sgs/gifs/ublogob.gif HTTP/1.0  200
# 99973              GET /pub/job/vk/vk-ad-15.jpg HTTP/1.0  200
# 99974      GET /pub/warnock/archie_warnock.html HTTP/1.0  200
# 99975        GET /pub/k2/am4x44u/gifs/jjbg2.jpg HTTP/1.0  200
# 99976            GET /pub/mikebilt/kinkbear.jpg HTTP/1.0  404
# 99977                GET /pub/job/vk/view04.jpg HTTP/1.0  200
# 99978          GET /pub/aztec/hans/hc43-03z.gif HTTP/1.0  200
# 99979        GET /pub/atomicbk/catalog/mini.gif HTTP/1.0  304
# 99980                   GET /pub/job/vk/bam.gif HTTP/1.0  200
# 99981           GET /pub/aztec/hans/hctitle.gif HTTP/1.0  200
# 99982            GET /pub/mbrophy/pix/thing.jpg HTTP/1.0  304
# 99983            GET /pub/mbrophy/pix/holly.jpg HTTP/1.0  304
# 99984                GET /pub/job/vk/view05.jpg HTTP/1.0  200
# 99985       GET /pub/atomicbk/catalog/logo2.gif HTTP/1.0  304
# 99986  GET /pub/ahasuer/heinlein/juan.rico.html HTTP/1.0  200
# 99987            GET /pub/mileskb/boc/news.html HTTP/1.0  304
# 99988              GET /pub/ashp/grafx/logo.jpg HTTP/1.0  200
# 99989         GET /pub/atomicbk/catalog/new.gif HTTP/1.0  200
# 99990                 GET /printing/E-CARD.html HTTP/1.0  200
# 99991          GET /pub/aztec/hans/hc43-01z.gif HTTP/1.0  200
# 99992             GET /pub/mileskb/boc/home.gif HTTP/1.0  304
# 99993             GET /pub/mileskb/boc/logo.gif HTTP/1.0  304
# 99994           GET /pub/mbrophy/pix/review.jpg HTTP/1.0  304
# 99995            GET /pub/mbrophy/pix/other.jpg HTTP/1.0  304
# 99996       GET /pub/atomicbk/images/stereo.gif HTTP/1.0  404
# 99997                         GET /pub/stc/www/ HTTP/1.0  200
# 99998            GET /pub/mbrophy/pix/about.jpg HTTP/1.0  304
# 99999                GET /pub/job/vk/view06.jpg HTTP/1.0  200
#
# [100000 rows x 4 columns]

# %% [markdown]
# We now move to the second issue: the need for splitting column 5 into 3. One very powerful way for doing so is to use the `extract` function. Since this may be hard to find how to properly use it, the code is given below. It is assumed that `df_` is the dataframe resulting from the drop odf the columns.

# %%
df_split =  df_[5].str.extract('(?P<Method>[A-Z]*) (?P<Resource>[^ ]+) (?P<Protocol>[^ ]+)', expand= True)
df_split
# Out:
#       Method                                    Resource  Protocol
# 0        GET  /pub/rmharris/catalogs/dawsocat/intro.html  HTTP/1.0
# 1        GET                      /pub/robert/past99.gif  HTTP/1.0
# 2        GET                      /pub/robert/curr99.gif  HTTP/1.0
# 3        GET          /pub/atomicbk/catalog/sleazbk.html  HTTP/1.0
# 4        GET                      /pub/job/vk/view17.jpg  HTTP/1.0
# 5        GET                     /pub/rjgula/network.htm  HTTP/1.0
# 6        GET                        /pub/k2/jeep/jxj.htm  HTTP/1.0
# 7        GET                      /pub/eurocent/home.htm  HTTP/1.0
# 8        GET              /pub/atomicbk/catalog/home.gif  HTTP/1.0
# 9        GET             /pub/atomicbk/catalog/logo2.gif  HTTP/1.0
# 10       GET           /pub/atomicbk/catalog/catalog.gif  HTTP/1.0
# 11       GET                      /pub/job/vk/view18.jpg  HTTP/1.0
# 12       GET                     /pub/eurocent/tiny2.gif  HTTP/1.0
# 13       GET                                  /atomicbk/  HTTP/1.0
# 14       GET                       /atomicbk/contest.gif  HTTP/1.0
# 15       GET                        /atomicbk/artgal.gif  HTTP/1.0
# 16       GET                         /atomicbk/email.gif  HTTP/1.0
# 17       GET                                           /  HTTP/1.0
# 18       GET               /pub/atomicbk/catalog/new.gif  HTTP/1.0
# 19       GET                         /atomicbk/promo.gif  HTTP/1.0
# 20       GET                          /atomicbk/news.gif  HTTP/1.0
# 21       GET                           /atomicbk/new.gif  HTTP/1.0
# 22       GET                       /atomicbk/catalog.gif  HTTP/1.0
# 23       GET                         /atomicbk/logo2.gif  HTTP/1.0
# 24       GET                        /atomicbk/emboss.jpg  HTTP/1.0
# 25       GET                        /atomicbk/direct.gif  HTTP/1.0
# 26       GET                      /pub/job/vk/v-line.gif  HTTP/1.0
# 27       GET                        /atomicbk/scotth.gif  HTTP/1.0
# 28       GET                     /pub/rjgula/network.htm  HTTP/1.0
# 29       GET                        /atomicbk/orders.gif  HTTP/1.0
# ...      ...                                         ...       ...
# 99970    GET                      /pub/sgs/gifs/ubbg.gif  HTTP/1.0
# 99971    GET                      /pub/job/vk/view19.jpg  HTTP/1.0
# 99972    GET                   /pub/sgs/gifs/ublogob.gif  HTTP/1.0
# 99973    GET                    /pub/job/vk/vk-ad-15.jpg  HTTP/1.0
# 99974    GET            /pub/warnock/archie_warnock.html  HTTP/1.0
# 99975    GET              /pub/k2/am4x44u/gifs/jjbg2.jpg  HTTP/1.0
# 99976    GET                  /pub/mikebilt/kinkbear.jpg  HTTP/1.0
# 99977    GET                      /pub/job/vk/view04.jpg  HTTP/1.0
# 99978    GET                /pub/aztec/hans/hc43-03z.gif  HTTP/1.0
# 99979    GET              /pub/atomicbk/catalog/mini.gif  HTTP/1.0
# 99980    GET                         /pub/job/vk/bam.gif  HTTP/1.0
# 99981    GET                 /pub/aztec/hans/hctitle.gif  HTTP/1.0
# 99982    GET                  /pub/mbrophy/pix/thing.jpg  HTTP/1.0
# 99983    GET                  /pub/mbrophy/pix/holly.jpg  HTTP/1.0
# 99984    GET                      /pub/job/vk/view05.jpg  HTTP/1.0
# 99985    GET             /pub/atomicbk/catalog/logo2.gif  HTTP/1.0
# 99986    GET        /pub/ahasuer/heinlein/juan.rico.html  HTTP/1.0
# 99987    GET                  /pub/mileskb/boc/news.html  HTTP/1.0
# 99988    GET                    /pub/ashp/grafx/logo.jpg  HTTP/1.0
# 99989    GET               /pub/atomicbk/catalog/new.gif  HTTP/1.0
# 99990    GET                       /printing/E-CARD.html  HTTP/1.0
# 99991    GET                /pub/aztec/hans/hc43-01z.gif  HTTP/1.0
# 99992    GET                   /pub/mileskb/boc/home.gif  HTTP/1.0
# 99993    GET                   /pub/mileskb/boc/logo.gif  HTTP/1.0
# 99994    GET                 /pub/mbrophy/pix/review.jpg  HTTP/1.0
# 99995    GET                  /pub/mbrophy/pix/other.jpg  HTTP/1.0
# 99996    GET             /pub/atomicbk/images/stereo.gif  HTTP/1.0
# 99997    GET                               /pub/stc/www/  HTTP/1.0
# 99998    GET                  /pub/mbrophy/pix/about.jpg  HTTP/1.0
# 99999    GET                      /pub/job/vk/view06.jpg  HTTP/1.0
#
# [100000 rows x 3 columns]

# %% [markdown]
# Now, you can concatenate the two dataframes (using the `concat` function) and drop the useless column 5.

# %%
df_concat = pd.concat([df_,df_split], axis=1)
df_concat = df_concat.drop(columns=[5])

# %% [markdown]
# We now move to the conversion of column 3 to datetime. Apply the folling methodology:
#   1. Delete the character `[` (use the function `replace`, e.g., `df[5].str.replace("@","")` remove the character `@` from the column 5) and store the result in a new column `Time` (column 3 can thus be dropped).
#   2. Use the `to_datetime` to convert the `Time` column into a datetime. Please refer to <http://strftime.org> for help about the format specification.

# %%
df_concat["Time"] = df_concat[3].str.replace("[","")
df = df_concat.drop(columns=[3])
df["Time"] = pd.to_datetime(df["Time"],format="%d/%b/%Y:%H:%M:%S")

# %%
df
# Out:
#                                             0    6 Method  \
# 0                              204.249.225.59  200    GET
# 1                         access9.accsyst.com  200    GET
# 2                         access9.accsyst.com  200    GET
# 3                               world.std.com  200    GET
# 4                            cssu24.cs.ust.hk  200    GET
# 5                             er6.rutgers.edu  200    GET
# 6                 cyclom1-1-6.intersource.com  200    GET
# 7              d24-1.cpe.Brisbane.aone.net.au  200    GET
# 8                               world.std.com  200    GET
# 9                               world.std.com  200    GET
# 10                              world.std.com  200    GET
# 11                           cssu24.cs.ust.hk  200    GET
# 12             d24-1.cpe.Brisbane.aone.net.au  200    GET
# 13                         ppp19.glas.apc.org  304    GET
# 14                         ppp19.glas.apc.org  304    GET
# 15                         ppp19.glas.apc.org  304    GET
# 16                         ppp19.glas.apc.org  304    GET
# 17                                ari.ari.net  200    GET
# 18                              world.std.com  200    GET
# 19                         ppp19.glas.apc.org  304    GET
# 20                         ppp19.glas.apc.org  304    GET
# 21                         ppp19.glas.apc.org  304    GET
# 22                         ppp19.glas.apc.org  304    GET
# 23                         ppp19.glas.apc.org  304    GET
# 24                         ppp19.glas.apc.org  304    GET
# 25                         ppp19.glas.apc.org  304    GET
# 26                           cssu24.cs.ust.hk  200    GET
# 27                         ppp19.glas.apc.org  200    GET
# 28                      freenet3.scri.fsu.edu  200    GET
# 29                         ppp19.glas.apc.org  304    GET
# ...                                       ...  ...    ...
# 99970                           sgs.clark.net  200    GET
# 99971                           141.192.47.25  200    GET
# 99972                           sgs.clark.net  200    GET
# 99973                     lspc41.nsls.bnl.gov  200    GET
# 99974                 scarpent.iac.gatech.edu  200    GET
# 99975                             146.9.7.243  200    GET
# 99976                         hntp2.hinet.net  404    GET
# 99977  hhh6.orgchemie.chemie.uni-tuebingen.de  200    GET
# 99978                   oed.saclantc.nato.int  200    GET
# 99979                    piweba4y.prodigy.com  304    GET
# 99980                   PPP-PORT10.xyplex.com  200    GET
# 99981                   oed.saclantc.nato.int  200    GET
# 99982                       ppp13.cac.psu.edu  304    GET
# 99983                       ppp13.cac.psu.edu  304    GET
# 99984  hhh6.orgchemie.chemie.uni-tuebingen.de  200    GET
# 99985                    piweba4y.prodigy.com  304    GET
# 99986                 dd11-015.compuserve.com  200    GET
# 99987                            147.160.8.12  304    GET
# 99988                      crc3-fddi.cris.com  200    GET
# 99989                    homer.scs.uottawa.ca  200    GET
# 99990                     ppp-nyc-5-4.ios.com  200    GET
# 99991                   oed.saclantc.nato.int  200    GET
# 99992                            147.160.8.12  304    GET
# 99993                            147.160.8.12  304    GET
# 99994                       ppp13.cac.psu.edu  304    GET
# 99995                       ppp13.cac.psu.edu  304    GET
# 99996                             205.206.4.2  404    GET
# 99997                     hnlp57.VERIFONE.COM  200    GET
# 99998                       ppp13.cac.psu.edu  304    GET
# 99999  hhh6.orgchemie.chemie.uni-tuebingen.de  200    GET
#
#                                          Resource  Protocol  \
# 0      /pub/rmharris/catalogs/dawsocat/intro.html  HTTP/1.0
# 1                          /pub/robert/past99.gif  HTTP/1.0
# 2                          /pub/robert/curr99.gif  HTTP/1.0
# 3              /pub/atomicbk/catalog/sleazbk.html  HTTP/1.0
# 4                          /pub/job/vk/view17.jpg  HTTP/1.0
# 5                         /pub/rjgula/network.htm  HTTP/1.0
# 6                            /pub/k2/jeep/jxj.htm  HTTP/1.0
# 7                          /pub/eurocent/home.htm  HTTP/1.0
# 8                  /pub/atomicbk/catalog/home.gif  HTTP/1.0
# 9                 /pub/atomicbk/catalog/logo2.gif  HTTP/1.0
# 10              /pub/atomicbk/catalog/catalog.gif  HTTP/1.0
# 11                         /pub/job/vk/view18.jpg  HTTP/1.0
# 12                        /pub/eurocent/tiny2.gif  HTTP/1.0
# 13                                     /atomicbk/  HTTP/1.0
# 14                          /atomicbk/contest.gif  HTTP/1.0
# 15                           /atomicbk/artgal.gif  HTTP/1.0
# 16                            /atomicbk/email.gif  HTTP/1.0
# 17                                              /  HTTP/1.0
# 18                  /pub/atomicbk/catalog/new.gif  HTTP/1.0
# 19                            /atomicbk/promo.gif  HTTP/1.0
# 20                             /atomicbk/news.gif  HTTP/1.0
# 21                              /atomicbk/new.gif  HTTP/1.0
# 22                          /atomicbk/catalog.gif  HTTP/1.0
# 23                            /atomicbk/logo2.gif  HTTP/1.0
# 24                           /atomicbk/emboss.jpg  HTTP/1.0
# 25                           /atomicbk/direct.gif  HTTP/1.0
# 26                         /pub/job/vk/v-line.gif  HTTP/1.0
# 27                           /atomicbk/scotth.gif  HTTP/1.0
# 28                        /pub/rjgula/network.htm  HTTP/1.0
# 29                           /atomicbk/orders.gif  HTTP/1.0
# ...                                           ...       ...
# 99970                      /pub/sgs/gifs/ubbg.gif  HTTP/1.0
# 99971                      /pub/job/vk/view19.jpg  HTTP/1.0
# 99972                   /pub/sgs/gifs/ublogob.gif  HTTP/1.0
# 99973                    /pub/job/vk/vk-ad-15.jpg  HTTP/1.0
# 99974            /pub/warnock/archie_warnock.html  HTTP/1.0
# 99975              /pub/k2/am4x44u/gifs/jjbg2.jpg  HTTP/1.0
# 99976                  /pub/mikebilt/kinkbear.jpg  HTTP/1.0
# 99977                      /pub/job/vk/view04.jpg  HTTP/1.0
# 99978                /pub/aztec/hans/hc43-03z.gif  HTTP/1.0
# 99979              /pub/atomicbk/catalog/mini.gif  HTTP/1.0
# 99980                         /pub/job/vk/bam.gif  HTTP/1.0
# 99981                 /pub/aztec/hans/hctitle.gif  HTTP/1.0
# 99982                  /pub/mbrophy/pix/thing.jpg  HTTP/1.0
# 99983                  /pub/mbrophy/pix/holly.jpg  HTTP/1.0
# 99984                      /pub/job/vk/view05.jpg  HTTP/1.0
# 99985             /pub/atomicbk/catalog/logo2.gif  HTTP/1.0
# 99986        /pub/ahasuer/heinlein/juan.rico.html  HTTP/1.0
# 99987                  /pub/mileskb/boc/news.html  HTTP/1.0
# 99988                    /pub/ashp/grafx/logo.jpg  HTTP/1.0
# 99989               /pub/atomicbk/catalog/new.gif  HTTP/1.0
# 99990                       /printing/E-CARD.html  HTTP/1.0
# 99991                /pub/aztec/hans/hc43-01z.gif  HTTP/1.0
# 99992                   /pub/mileskb/boc/home.gif  HTTP/1.0
# 99993                   /pub/mileskb/boc/logo.gif  HTTP/1.0
# 99994                 /pub/mbrophy/pix/review.jpg  HTTP/1.0
# 99995                  /pub/mbrophy/pix/other.jpg  HTTP/1.0
# 99996             /pub/atomicbk/images/stereo.gif  HTTP/1.0
# 99997                               /pub/stc/www/  HTTP/1.0
# 99998                  /pub/mbrophy/pix/about.jpg  HTTP/1.0
# 99999                      /pub/job/vk/view06.jpg  HTTP/1.0
#
#                      Time
# 0     1995-08-28 00:00:34
# 1     1995-08-28 00:00:35
# 2     1995-08-28 00:00:35
# 3     1995-08-28 00:00:36
# 4     1995-08-28 00:00:36
# 5     1995-08-28 00:00:37
# 6     1995-08-28 00:00:37
# 7     1995-08-28 00:00:38
# 8     1995-08-28 00:00:38
# 9     1995-08-28 00:00:38
# 10    1995-08-28 00:00:38
# 11    1995-08-28 00:00:39
# 12    1995-08-28 00:00:40
# 13    1995-08-28 00:00:43
# 14    1995-08-28 00:00:43
# 15    1995-08-28 00:00:44
# 16    1995-08-28 00:00:44
# 17    1995-08-28 00:00:45
# 18    1995-08-28 00:00:45
# 19    1995-08-28 00:00:45
# 20    1995-08-28 00:00:45
# 21    1995-08-28 00:00:46
# 22    1995-08-28 00:00:46
# 23    1995-08-28 00:00:46
# 24    1995-08-28 00:00:46
# 25    1995-08-28 00:00:46
# 26    1995-08-28 00:00:46
# 27    1995-08-28 00:00:48
# 28    1995-08-28 00:00:48
# 29    1995-08-28 00:00:48
# ...                   ...
# 99970 1995-08-28 12:41:55
# 99971 1995-08-28 12:41:55
# 99972 1995-08-28 12:41:55
# 99973 1995-08-28 12:41:55
# 99974 1995-08-28 12:41:56
# 99975 1995-08-28 12:41:56
# 99976 1995-08-28 12:41:56
# 99977 1995-08-28 12:41:56
# 99978 1995-08-28 12:41:56
# 99979 1995-08-28 12:41:56
# 99980 1995-08-28 12:41:56
# 99981 1995-08-28 12:41:57
# 99982 1995-08-28 12:41:57
# 99983 1995-08-28 12:41:57
# 99984 1995-08-28 12:41:57
# 99985 1995-08-28 12:41:58
# 99986 1995-08-28 12:41:58
# 99987 1995-08-28 12:41:58
# 99988 1995-08-28 12:41:58
# 99989 1995-08-28 12:41:58
# 99990 1995-08-28 12:41:58
# 99991 1995-08-28 12:41:58
# 99992 1995-08-28 12:41:58
# 99993 1995-08-28 12:41:58
# 99994 1995-08-28 12:41:59
# 99995 1995-08-28 12:41:59
# 99996 1995-08-28 12:41:59
# 99997 1995-08-28 12:41:59
# 99998 1995-08-28 12:42:00
# 99999 1995-08-28 12:42:00
#
# [100000 rows x 6 columns]

# %% [markdown]
# Il's almost ok. The last thing to do is to change the column name (when needed). For this, use the `rename` function.

# %%
df = df.rename(columns={0:"Host", 6:"Status"})

# %% [markdown]
# ### Data Cleaning
# Firsgt, remove rows such that the returned status code in not in the interval \[200;400\[ and that do not concern non HTML resources (we can make the oversimplistic assumption that the resource must contazins the substring `.html` to be considered as an HTML page.

# %%
df = df[(df["Status"] >= 200) & (df["Status"]<400) & (df["Resource"].str.contains(".htm"))]

# %%
df
# Out:
#                                  Host  Status Method  \
# 0                      204.249.225.59     200    GET
# 3                       world.std.com     200    GET
# 5                     er6.rutgers.edu     200    GET
# 6         cyclom1-1-6.intersource.com     200    GET
# 7      d24-1.cpe.Brisbane.aone.net.au     200    GET
# 28              freenet3.scri.fsu.edu     200    GET
# 31              kuts4p01.cc.ukans.edu     200    GET
# 36     d24-1.cpe.Brisbane.aone.net.au     200    GET
# 37               piweba4y.prodigy.com     200    GET
# 38                Loki.async.smsu.edu     200    GET
# 42           SLIP4A-03.DIALIN.UIC.EDU     200    GET
# 43              freenet3.scri.fsu.edu     200    GET
# 44              kuts4p01.cc.ukans.edu     200    GET
# 46                  shep102.wustl.edu     200    GET
# 51                       165.113.1.43     200    GET
# 54                    er6.rutgers.edu     200    GET
# 56                 ppp19.glas.apc.org     304    GET
# 65              prpayne-ppp.clark.net     200    GET
# 74               www-b6.proxy.aol.com     304    GET
# 81                        ari.ari.net     200    GET
# 84     d24-1.cpe.Brisbane.aone.net.au     200    GET
# 88        pwpark.remote.Princeton.EDU     200    GET
# 94        pwpark.remote.Princeton.EDU     200    GET
# 95                Loki.async.smsu.edu     200    GET
# 98        pwpark.remote.Princeton.EDU     200    GET
# 101                 shep102.wustl.edu     200    GET
# 109       pwpark.remote.Princeton.EDU     200    GET
# 112                    137.198.11.104     200    GET
# 121                     204.50.56.205     200    GET
# 124             ppp-mia-94.shadow.net     200    GET
# ...                               ...     ...    ...
# 99869      olli.biosci.ohio-state.edu     200    GET
# 99871         sam-slip-f3.NeoSoft.COM     200    GET
# 99872         pmeA03.cworld.awinc.com     200    GET
# 99881              crc6-fddi.cris.com     200    GET
# 99884                  140.229.23.150     200    GET
# 99888                  141.211.225.55     200    GET
# 99890            condor.coacade.uv.mx     200    GET
# 99892                 larryr.nosc.mil     200    GET
# 99893          orcafakanc.wr.usgs.gov     200    GET
# 99896                     146.9.7.243     200    GET
# 99904              eurocent.clark.net     200    GET
# 99911              hankjr.berksys.com     200    GET
# 99913               ppp13.cac.psu.edu     200    GET
# 99915          MTASKNX16.MTAS.UTK.EDU     200    GET
# 99926       pppurw184.asahi-net.or.jp     200    GET
# 99931        line153.nwm.mindlink.net     200    GET
# 99934              crc3-fddi.cris.com     200    GET
# 99936                     gw3.att.com     304    GET
# 99938                   204.241.70.36     304    GET
# 99942           oed.saclantc.nato.int     200    GET
# 99945                     r2d2.sci.fi     200    GET
# 99947        ix-oma1-24.ix.netcom.com     200    GET
# 99948                 port115.mhv.net     200    GET
# 99950        ix-prn1-05.ix.netcom.com     200    GET
# 99959                   sgs.clark.net     200    GET
# 99967              vagrant.vf.mmc.com     200    GET
# 99974         scarpent.iac.gatech.edu     200    GET
# 99986         dd11-015.compuserve.com     200    GET
# 99987                    147.160.8.12     304    GET
# 99990             ppp-nyc-5-4.ios.com     200    GET
#
#                                               Resource  Protocol  \
# 0           /pub/rmharris/catalogs/dawsocat/intro.html  HTTP/1.0
# 3                   /pub/atomicbk/catalog/sleazbk.html  HTTP/1.0
# 5                              /pub/rjgula/network.htm  HTTP/1.0
# 6                                 /pub/k2/jeep/jxj.htm  HTTP/1.0
# 7                               /pub/eurocent/home.htm  HTTP/1.0
# 28                             /pub/rjgula/network.htm  HTTP/1.0
# 31                                /pub/sshay/home.html  HTTP/1.0
# 36                            /pub/eurocent/german.htm  HTTP/1.0
# 37                                 /larouche/waco.html  HTTP/1.0
# 38                    /pub/ahasuer/heinlein/about.html  HTTP/1.0
# 42                      /atomicbk/catalog/catalog.html  HTTP/1.0
# 43                                  /pub/rjgula/os.htm  HTTP/1.0
# 44                                /pub/sshay/home.html  HTTP/1.0
# 46                              /pub/pribut/chess.html  HTTP/1.0
# 51                             /pub/atomicbk/home.html  HTTP/1.0
# 54                             /pub/rjgula/attacks.htm  HTTP/1.0
# 56                              /atomicbk/new/new.html  HTTP/1.0
# 65                              /pub/show/tickets.html  HTTP/1.0
# 74                 /pub/networx/autopage/autopage.html  HTTP/1.0
# 81                                      /html/faq.html  HTTP/1.0
# 84                             /pub/eurocent/koln9.htm  HTTP/1.0
# 88                          /pub/peace/PeaceCorps.html  HTTP/1.0
# 94                         /pub/peace/PeaceCorps1.html  HTTP/1.0
# 95                    /pub/ahasuer/heinlein/order.html  HTTP/1.0
# 98                                /pub/peace/VRS1.html  HTTP/1.0
# 101                           /pub/pribut/spsport.html  HTTP/1.0
# 109                               /pub/peace/VRS3.html  HTTP/1.0
# 112                /pub/atomicbk/catalog/adultcom.html  HTTP/1.0
# 121                           /pub/mikebilt/gaydc.html  HTTP/1.0
# 124                           /pub/robert/current.html  HTTP/1.0
# ...                                                ...       ...
# 99869              /pub/networx/autopage/autopage.html  HTTP/1.0
# 99871  /pub/alweiner/cgi-bin/squiggle.html?T+w3magic13  HTTP/1.0
# 99872                           /pub/listserv/wsg.html  HTTP/1.0
# 99881                            /pub/jeffd/final.html  HTTP/1.0
# 99884                       /pub/cybersoft/search.html  HTTP/1.0
# 99888                     /pub/journalism/awesome.html  HTTP/1.0
# 99890                        /pub/listserv/atom1a.html  HTTP/1.0
# 99892                /html/usage/usage.graph.small.gif  HTTP/1.0
# 99893                   /atomicbk/catalog/privacy.html  HTTP/1.0
# 99896                            /pub/k2/jeep/jeep.htm  HTTP/1.0
# 99904                           /pub/eurocent/amb3.htm  HTTP/1.0
# 99911                             /theme/vwfactez.html  HTTP/1.0
# 99913                /pub/mbrophy/the_sandra_page.html  HTTP/1.0
# 99915                       /pub/phil/WinonaRyder.html  HTTP/1.0
# 99926                 /pub/atomicbk/catalog/pinup.html  HTTP/1.0
# 99931       /pub/k2/am4x44u/truck_stop/parts/parts.htm  HTTP/1.0
# 99934                             /pub/ashp/index.html  HTTP/1.0
# 99936                     /pub/journalism/awesome.html  HTTP/1.0
# 99938                          /pub/mharding/Rage.html  HTTP/1.0
# 99942                        /pub/aztec/hans/home.html  HTTP/1.0
# 99945                           /atomicbk/shocked.html  HTTP/1.0
# 99947                          /pub/rjgula/network.htm  HTTP/1.0
# 99948               /pub/bell/review/book_review.shtml  HTTP/1.0
# 99950                           /pub/pgarrett/pmo.html  HTTP/1.0
# 99959                            /pub/sgs/uboahome.htm  HTTP/1.0
# 99967                               /pub/wsg/html/jan/  HTTP/1.0
# 99974                 /pub/warnock/archie_warnock.html  HTTP/1.0
# 99986             /pub/ahasuer/heinlein/juan.rico.html  HTTP/1.0
# 99987                       /pub/mileskb/boc/news.html  HTTP/1.0
# 99990                            /printing/E-CARD.html  HTTP/1.0
#
#                      Time
# 0     1995-08-28 00:00:34
# 3     1995-08-28 00:00:36
# 5     1995-08-28 00:00:37
# 6     1995-08-28 00:00:37
# 7     1995-08-28 00:00:38
# 28    1995-08-28 00:00:48
# 31    1995-08-28 00:00:49
# 36    1995-08-28 00:00:55
# 37    1995-08-28 00:00:55
# 38    1995-08-28 00:00:55
# 42    1995-08-28 00:00:57
# 43    1995-08-28 00:00:59
# 44    1995-08-28 00:01:00
# 46    1995-08-28 00:01:01
# 51    1995-08-28 00:01:04
# 54    1995-08-28 00:01:06
# 56    1995-08-28 00:01:07
# 65    1995-08-28 00:01:10
# 74    1995-08-28 00:01:12
# 81    1995-08-28 00:01:15
# 84    1995-08-28 00:01:17
# 88    1995-08-28 00:01:18
# 94    1995-08-28 00:01:21
# 95    1995-08-28 00:01:22
# 98    1995-08-28 00:01:25
# 101   1995-08-28 00:01:27
# 109   1995-08-28 00:01:30
# 112   1995-08-28 00:01:31
# 121   1995-08-28 00:01:37
# 124   1995-08-28 00:01:40
# ...                   ...
# 99869 1995-08-28 12:41:37
# 99871 1995-08-28 12:41:37
# 99872 1995-08-28 12:41:37
# 99881 1995-08-28 12:41:38
# 99884 1995-08-28 12:41:38
# 99888 1995-08-28 12:41:39
# 99890 1995-08-28 12:41:39
# 99892 1995-08-28 12:41:39
# 99893 1995-08-28 12:41:40
# 99896 1995-08-28 12:41:41
# 99904 1995-08-28 12:41:42
# 99911 1995-08-28 12:41:43
# 99913 1995-08-28 12:41:43
# 99915 1995-08-28 12:41:44
# 99926 1995-08-28 12:41:46
# 99931 1995-08-28 12:41:47
# 99934 1995-08-28 12:41:47
# 99936 1995-08-28 12:41:47
# 99938 1995-08-28 12:41:48
# 99942 1995-08-28 12:41:49
# 99945 1995-08-28 12:41:49
# 99947 1995-08-28 12:41:49
# 99948 1995-08-28 12:41:49
# 99950 1995-08-28 12:41:50
# 99959 1995-08-28 12:41:53
# 99967 1995-08-28 12:41:55
# 99974 1995-08-28 12:41:56
# 99986 1995-08-28 12:41:58
# 99987 1995-08-28 12:41:58
# 99990 1995-08-28 12:41:58
#
# [19050 rows x 6 columns]

# %% [markdown]
# ### User identification
# All we have to identify users is the IP address. We will thus use it to split the dataset into groups having the same IP address. Use the `group_by` function for doing so.

# %%
gb = df.groupby(["Host"])

# %% [markdown]
# ### Sessionization
# To sessionize the dataset we will use the following time-oriented heuristic: the interval between the vist of 2 pages must not exceed 15 minutes. To implement this heuristic, apply the following methodology:
#   1. Iterate over all the groups (one group per user)
#   2. For each group, iterate over the accessed resources anc check if the heuristic holds.
#
# The expected format is the following: a list of lists where each nested list represents a session. Notice that we lost the user information with this format but that at this point is not anymore of interest.
#
# Example:
#
#
#     [['p1.html', 'p2.html','p1.html'], ['p2.html', 'p3.html'], ...]

# %%
def h1(g, interval=15) : 
    interval_seconds = interval * 60
    res = []
    values = g.values
    for i,row in enumerate(values) : 
        if i == 0 : 
            res.append([row[3]])
        else : 
            delta = row[-1] - values[i-1][-1]
            
            if delta.total_seconds() <= interval_seconds : 
                res[-1].append(row[3])
            else : 
                res.append([row[3]])
    return res
sessions = []        
for h in df["Host"].unique() : 
    group = gb.get_group(h)
    #print(group)
    for s in h1(group) : 
        sessions.append(s)

sessions
# Out:
# [['/pub/rmharris/catalogs/dawsocat/intro.html',
#   '/pub/rmharris/catalogs/dawsocat/530-3.html',
#   '/pub/rmharris/catalogs/dawsocat/530-3.html',
#   '/pub/rmharris/catalogs/dawsocat/530-3.html',
#   '/pub/rmharris/catalogs.html',
#   '/pub/rmharris/catalogs/onealcat/intro.html',
#   '/pub/rmharris/catalogs/onealcat/109n-3.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/pribut/spsport.html',
#   '/pub/pribut/spinjur.html',
#   '/pub/pribut/heelhtm.html',
#   '/pub/pribut/finadoc.html',
#   '/pub/pribut/sporgs.html',
#   '/pub/pribut/sporgs.html',
#   '/pub/pribut/spsport.html',
#   '/pub/pribut/spshoe.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/rjgula/network.htm', '/pub/rjgula/attacks.htm'],
#  ['/pub/rjgula/faqs.htm'],
#  ['/pub/rjgula/network.htm', '/pub/rjgula/os.htm'],
#  ['/pub/k2/jeep/jxj.htm',
#   '/pub/k2/jeep/jyj.htm',
#   '/pub/k2/jeep/jzj.htm',
#   '/pub/k2/jeep/jcj.htm',
#   '/pub/k2/jeep/jeep2.htm',
#   '/pub/k2/jeep/jeeporg.htm',
#   '/pub/k2/am4x44u/events/clubs/jcoa.htm',
#   '/pub/k2/am4x44u/events/clubs/jeepreg.htm'],
#  ['/pub/eurocent/home.htm',
#   '/pub/eurocent/german.htm',
#   '/pub/eurocent/koln9.htm'],
#  ['/pub/rjgula/network.htm', '/pub/rjgula/os.htm'],
#  ['/pub/ibos/fishform.html'],
#  ['/pub/k2/am4x44u/4x4.html',
#   '/pub/k2/am4x44u/truck_stop/truck_stop.htm',
#   '/pub/k2/am4x44u/truck_stop/parts/parts.htm',
#   '/pub/k2/am4x44u/truck_stop/parts/swinch.htm',
#   '/pub/k2/am4x44u/truck_stop/parts/swhusky.htm'],
#  ['/pub/sshay/home.html', '/pub/sshay/home.html'],
#  ['/larouche/waco.html',
#   '/larouche/Quacks.html',
#   '/pub/speakers/web/spkr1065.html',
#   '/pub/atomicbk/catalog/sleazmag.html',
#   '/pub/journalism/awesome.html',
#   '/pub/wick/req.html',
#   '/pub/wick/index.html',
#   '/pub/wick/q.html',
#   '/pub/wick/t.html',
#   '/pub/wick/personal.html',
#   '/pub/jeffd/index.html',
#   '/pub/jeffd/reading.html'],
#  ['/pub/jeffd/keyes_96.html',
#   '/pub/wine/home.html',
#   '/pub/wine/advocate.html',
#   '/pub/wine/main.html',
#   '/pub/journalism/awesome.html',
#   '/pub/murple/html/music.html',
#   '/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/classic.html',
#   '/pub/networx/autopage/advertise.html',
#   '/pub/journalism/awesome.html',
#   '/pub/networx/autopage/exotic.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/ashp/index.html',
#   '/pub/ashp/pharmnet.htm',
#   '/pub/ashp/guestbk.htm'],
#  ['/pub/lschank/web/country.html', '/pub/lschank/web/subject.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/mbrophy/the_sandra_page.html',
#   '/pub/terra/laker.html',
#   '/pub/terra/index.html'],
#  ['/pub/russadam/barcode1.html'],
#  ['/pub/lazarus/citadel/cithome.htm',
#   '/pub/murple/html/drugs.html',
#   '/pub/murple/home.html',
#   '/pub/murple/html/www.html'],
#  ['/pub/jeffd/index.html', '/pub/jeffd/reading.html'],
#  ['/pub/job/vk/vendela.html', '/pub/jumpsam/gospain.htm'],
#  ['/pub/jeffd/rushpage.html',
#   '/pub/jeffd/college.html',
#   '/pub/jeffd/view.html',
#   '/pub/jeffd/mr_newt.html',
#   '/pub/journalism/awesome.html',
#   '/html/usage/usage.graph.small.gif',
#   '/home1.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/verbwork.html',
#   '/html/people.html',
#   '/pub/global/index1.html',
#   '/html/it.html',
#   '/html/it-about.html',
#   '/html/cgi.html',
#   '/home.html',
#   '/html/link.html',
#   '/pub/journalism/publish.html'],
#  ['/html/usage/usage.graph.small.gif', '/pub/journalism/awesome.html'],
#  ['/pub/jeffd/mr_newt.html',
#   '/pub/journalism/awesome.html',
#   '/pub/jeffd/view.html',
#   '/pub/jeffd/mr_newt.html',
#   '/pub/k2/suv/suv.htm',
#   '/pub/k2/suv/suvindex.htm',
#   '/pub/k2/suv/suv2.htm'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/ahasuer/heinlein/about.html',
#   '/pub/ahasuer/heinlein/order.html',
#   '/pub/ahasuer/heinlein/first.html',
#   '/pub/ahasuer/heinlein/stinkeroos.html',
#   '/pub/ahasuer/heinlein/difference.html',
#   '/pub/wmcbrine/html/Madonna.html',
#   '/pub/wmcbrine/html/encyc1s.gif',
#   '/pub/wmcbrine/html/tridon4.gif'],
#  ['/atomicbk/catalog/catalog.html', '/atomicbk/catalog/sleazmag.html'],
#  ['/pub/pribut/chess.html',
#   '/pub/pribut/spsport.html',
#   '/pub/pribut/sphome.html',
#   '/pub/pribut/spfide.html'],
#  ['/pub/atomicbk/home.html'],
#  ['/atomicbk/new/new.html'],
#  ['/pub/show/tickets.html',
#   '/pub/show/tickets.html',
#   '/pub/show/tickets.html',
#   '/pub/show/tickets.html',
#   '/pub/show/usbinfo.html'],
#  ['/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/exotic.html',
#   '/pub/networx/autopage/advertise.html',
#   '/pub/networx/autopage/exotic/ex001.html',
#   '/pub/networx/autopage/exotic/ex002.html',
#   '/pub/networx/autopage/exotic/ex002p.html',
#   '/pub/networx/autopage/classic.html',
#   '/pub/networx/autopage/dealers.html',
#   '/pub/networx/autopage/dealers/de001.html',
#   '/pub/networx/autopage/dealers/de001_a.html',
#   '/pub/networx/autopage/manu.html',
#   '/pub/networx/autopage/sales.html',
#   '/pub/networx/networx.html',
#   '/pub/robert/current.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/html/people.html',
#   '/html/beacon.html',
#   '/larouche/welcome.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/atomicbk/new/newjul15.html',
#   '/pub/sshay/gallery.html'],
#  ['/pub/kiaman/lyingcow.html', '/pub/kiaman/vanuatu.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/journalism/awesome.html', '/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/catalog.html',
#   '/pub/phil/home.html',
#   '/atomicbk/catalog/zines.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/mikebilt/gaydc.html'],
#  ['/pub/stc/www/conf.html', '/pub/sshay/home.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/sleazmag.html',
#   '/pub/job/vk/vendela.html',
#   '/larouche/welcome.html',
#   '/larouche/campaign_info.html',
#   '/pub/sshay/home.html',
#   '/pub/atomicbk/catalog/erotica.html'],
#  ['/html/faq.html', '/html/services.html', '/html/clarknet.html'],
#  ['/pub/peace/PeaceCorps.html',
#   '/pub/peace/PeaceCorps1.html',
#   '/pub/peace/VRS1.html',
#   '/pub/peace/VRS3.html',
#   '/pub/peace/VRS9.html',
#   '/pub/peace/FAQ4.html',
#   '/pub/peace/FAQ6.html',
#   '/pub/peace/MI1.html',
#   '/pub/peace/MI4.html',
#   '/pub/peace/MI5.html',
#   '/pub/peace/DP1.html',
#   '/pub/peace/WWS1.html',
#   '/pub/peace/OPSR3.html',
#   '/pub/peace/Fellows1.html',
#   '/pub/peace/Fellows6.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/mikebilt/gaydc.html'],
#  ['/pub/robert/current.html',
#   '/html/people.html',
#   '/pub/phil/index.html',
#   '/pub/robert/back.html',
#   '/pub/robert/081895.html'],
#  ['/pub/k2/suv/suv.htm', '/pub/k2/suv/suvindex.htm'],
#  ['/pub/pribut/spgait.html'],
#  ['/pub/jeffd/rushpage.html',
#   '/pub/journalism/awesome.html',
#   '/pub/atomicbk/catalog/sleazbk.html',
#   '/pub/speakers/web/spkr1019.html'],
#  ['/pub/russadam/barcode1.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/rsjdfg/Pictures.html',
#   '/pub/rsjdfg/ActII.html',
#   '/pub/rsjdfg/Confrontation.html',
#   '/pub/rsjdfg/Finale.html',
#   '/pub/rsjdfg/ActI.html',
#   '/pub/rsjdfg/Why.html',
#   '/pub/rsjdfg/Transaction.html',
#   '/html/services.html',
#   '/pub/rsjdfg/Last.html',
#   '/pub/rsjdfg/Touch.html',
#   '/pub/wmcbrine/html/Madonna.html',
#   '/pub/wmcbrine/html/encyc1s.gif',
#   '/pub/wmcbrine/html/tridon4.gif'],
#  ['/pub/job/vk/vendela.html',
#   '/pub/mbrophy/the_sandra_page.html',
#   '/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/murple/html/sex.html',
#   '/pub/madsox/ma-links.html',
#   '/pub/k2/am4x44u/4x4.html',
#   '/pub/k2/am4x44u/trails/locations/locations.htm',
#   '/pub/k2/am4x44u/trails/trailrep.htm',
#   '/pub/k2/am4x44u/trails/redrock.htm'],
#  ['/pub/jridgely/dc/union.html'],
#  ['/pub/sshay/gallery.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/wmcbrine/html/Madonna.html'],
#  ['/pub/phil/JulianaHatfield.html',
#   '/pub/phil/JulianaHatfieldLyrics.html',
#   '/pub/phil/JulianaHatfield/lyrics/LP_become_what_you_are.html',
#   '/pub/phil/JulianaHatfield/lyrics/LP_hey_babe.html'],
#  ['/pub/atomicbk/catalog/catalog.html', '/pub/sshay/home.html'],
#  ['/pub/jeffd/contract.html', '/pub/wick/photos.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/mbrophy/the_sandra_page.html'],
#  ['/pub/job/swim/swim.html'],
#  ['/pub/jeffd/mr_newt.html',
#   '/pub/aztec/capquest/home.html',
#   '/pub/aztec/capquest/mailform.html',
#   '/pub/aztec/capquest/procapt.html',
#   '/pub/aztec/capquest/capquest.html',
#   '/pub/aztec/capquest/home.html',
#   '/pub/aztec/capquest/mailform.html',
#   '/pub/aztec/capquest/capquest.html'],
#  ['/pub/jgbustam/coloquio/coloquio.html',
#   '/pub/jgbustam/coloquio/0695indx.html',
#   '/pub/jgbustam/coloquio/refran.html',
#   '/pub/jgbustam/coloquio/mario.html',
#   '/pub/jgbustam/coloquio/ana.html',
#   '/pub/jgbustam/coloquio/0895indx.html',
#   '/pub/jgbustam/coloquio/elena.html',
#   '/pub/jgbustam/coloquio/0495indx.html',
#   '/pub/jgbustam/coloquio/javier.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/terra/nba.html',
#   '/pub/sshay/gallery.html',
#   '/pub/mbrophy/the_sandra_page.html',
#   '/pub/sshay/links.html',
#   '/pub/sshay/links.html',
#   '/pub/sshay/paul.html',
#   '/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/pribut/spsport.html',
#   '/pub/pribut/spinjur.html',
#   '/pub/networx/autopage/classic.html',
#   '/pub/journalism/awesome.html',
#   '/pub/networx/autopage/classic/cl002.html',
#   '/pub/journalism/gburg.html',
#   '/pub/jeffd/cgi-bin/ngquote.html',
#   '/pub/jeffd/index.html'],
#  ['/pub/mbrophy/the_sandra_page.html'],
#  ['/pub/jeffd/mr_newt.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/rjamesd/holycros.html', '/pub/job/vk/vendela.html'],
#  ['/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/exotic.html',
#   '/pub/networx/autopage/exotic/ex002.html',
#   '/pub/networx/autopage/exotic/ex002p.html'],
#  ['/pub/wmcbrine/html/Madonna.html',
#   '/pub/wmcbrine/html/encyc1s.gif',
#   '/pub/wmcbrine/html/tridon4.gif'],
#  ['/pub/job/vk/vendela.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/pub/journalism/awesome.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newaug25.html',
#   '/pub/atomicbk/new/new.html',
#   '/atomicbk/new/newjul15.html',
#   '/pub/journalism/awesome.html',
#   '/pub/sshay/about.html',
#   '/pub/sshay/interact.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/jeffd/index.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/lschank/web/census.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newaug25.html',
#   '/atomicbk/new/newjul15.html',
#   '/pub/atomicbk/new/new.html',
#   '/pub/dsmith/allbright/NorthernVA.html',
#   '/pub/phil/WinonaRyder.html',
#   '/pub/sshay/gallery.html'],
#  ['/pub/atomicbk/new/newjul15.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/sshay/gallery.html', '/pub/wendi/home.html'],
#  ['/pub/jeffd/index.html', '/pub/jeffd/cgi-bin/ngquote.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/atomicbk/home.html', '/pub/atomicbk/home.html'],
#  ['/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/mayhem.html',
#   '/atomicbk/catalog/tattoo.html',
#   '/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html'],
#  ['/pub/royfc/ru_lingo.html'],
#  ['/html/usage/usage.graph.small.gif'],
#  ['/pub/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/sleazmag.html',
#   '/atomicbk/catalog/catalog.html'],
#  ['/pub/usenet-b/www/home.html'],
#  ['/pub/listserv/lsmus1.html',
#   '/pub/listserv/imag.html',
#   '/pub/listserv/impur1.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/global/toc.html',
#   '/pub/global/front.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html', '/atomicbk/images/gallery.html'],
#  ['/theme/cgi-bin/serch.html'],
#  ['/pub/robert/current.html'],
#  ['/pub/gen/mswg/msbb/index.html',
#   '/pub/lazarus/irc/welcome.htm',
#   '/pub/listserv/lsall1.html',
#   '/pub/jeffd/stat-http.html',
#   '/pub/jridgely/dc/arlcem.html'],
#  ['/pub/grinch/index.html',
#   '/pub/grinch/Fun.html',
#   '/pub/rmharris/catalogs/blksncat/95f3.html',
#   '/pub/teallen/eps/dietz.html',
#   '/pub/nkosi/home.html',
#   '/pub/czech/intro.html',
#   '/pub/pjs/linux.html',
#   '/pub/innanen/magic_madeup.html',
#   '/pub/howie/OO/ooterms.html',
#   '/pub/aztec/iso9000/home.html',
#   '/pub/sknight/contact.html',
#   '/pub/lschank/best/govdoc.html',
#   '/pub/meridian/www/htdocs/newsletter/merpas2a.html',
#   '/pub/karney/myhome.html',
#   '/pub/reed/ForeRunner.html',
#   '/pub/czech/consult0.html',
#   '/pub/ahasuer/heinlein/notes.and.acronyms.html',
#   '/pub/wrmi/201har.htm',
#   '/pub/jallen/home.html',
#   '/pub/gen/fas/irp/index.html',
#   '/pub/chivato/progressded.html',
#   '/pub/network/employer.html',
#   '/pub/cme/html/l-facts.html',
#   '/pub/rt/labels.html',
#   '/pub/wrmi/204dean.htm',
#   '/aztec/shesails/home.html',
#   '/pub/terra/dc.html',
#   '/pub/micros/consul/microall.html',
#   '/pub/network/jobs/60629S.html',
#   '/pub/lschank/explore/intro.html',
#   '/pub/rmharris/catalogs/oakkncat/74001-35.html',
#   '/pub/murple/html/cyberfreedom.html',
#   '/pub/ari/intro.html',
#   '/pub/macgyver/home.html',
#   '/pub/carlaron/carl_jumplist.html',
#   '/pub/terra/mail.html',
#   '/pub/lwallach/dick.html',
#   '/pub/k2/am4x44u/events/clubs/dccruiser.htm',
#   '/pub/pgarrett/lca/lca.htm',
#   '/pub/robert/home.html',
#   '/pub/jumpsam/index.htm',
#   '/pub/global/www.html',
#   '/pub/listserv/lslaw1b.html',
#   '/pub/lupine/www/lionking.html',
#   '/pub/listserv/lslsbn1.html',
#   '/pub/pb3/MCCA_Home.html',
#   '/pub/rothman/teleread.html',
#   '/pub/cwilkins/rfpi/rfpi.html',
#   '/pub/shelby/imag.html',
#   '/pub/winfield/brian.html',
#   '/pub/rmharris/research/lib8.html',
#   '/pub/rarnold/resume.html',
#   '/pub/k2/am4x44u/truck_tech/truck_tech.htm',
#   '/pub/rmharris/newsltr/newsltr.html',
#   '/pub/bell/review/mystery/index.shtml',
#   '/pub/epchurch/flanagan.htm',
#   '/pub/howie/home.html',
#   '/pub/terra/jobs.html',
#   '/pub/wilsey/form1.html',
#   '/pub/lupine/www/mail.html',
#   '/pub/rarnold/skills.html',
#   '/pub/bell/review/mystery/dunning_bookmans_wake.shtml',
#   '/pub/k2/am4x44u/whats_new/whats_new.htm',
#   '/pub/arthur/faq.html',
#   '/pub/murple/html/music.html',
#   '/pub/mitchlev/micro.html',
#   '/theme/factinfo.html',
#   '/pub/downin/cgi-bin/arlonet.html',
#   '/pub/ghoti/glil/INDEX.html',
#   '/pub/s-gray/sarah.html',
#   '/pub/ari/chemnet.html',
#   '/pub/pribut/chess.html',
#   '/pub/atomicbk/huffines.html',
#   '/pub/ecn/fresco.html',
#   '/pub/lschank/web/foreign.html',
#   '/pub/nractive/welcome.html',
#   '/pub/madsox/lameco.html',
#   '/pub/mdb/bstar.html',
#   '/pub/listserv/top40.html',
#   '/pub/stevi/ridez.html',
#   '/pub/global/weather.html',
#   '/pub/murple/index.html',
#   '/pub/bdalzell/wolf/wolfpark.html',
#   '/pub/jgbustam/coloquio/jb.html',
#   '/pub/usenet-b/www/bible-faq.html',
#   '/pub/jeffd/audio.html',
#   '/pub/listserv/lsall1c.html',
#   '/pub/jellybn/jellybn.html',
#   '/pub/jgbustam/famosos/alpha.html',
#   '/pub/s-gray/embassy/embassy.html',
#   '/pub/micros/forbes/index.html',
#   '/pub/lschank/web/k-12.html',
#   '/pub/atomicbk/tshirt.html',
#   '/pub/abaa-booknet/booknet1.html',
#   '/pub/theme/vrml.html',
#   '/pub/TMC/functions.html',
#   '/pub/global/legal.html',
#   '/pub/networx/autopage/dealers/de001_8.html',
#   '/pub/crewdson/under.html',
#   '/pub/aztec/hans/home.html',
#   '/pub/csamsi/html/release.html',
#   '/pub/jeffd/castww.html',
#   '/pub/guardian/www/arizona.html',
#   '/pub/grinch/Frequent.html',
#   '/pub/mikebilt/mike.html',
#   '/pub/mmuller/reunion95.html',
#   '/pub/rebel/stuff.html',
#   '/pub/meridian/www/htdocs/msi_home_txt.html',
#   '/pub/jumpsam/morspain.htm',
#   '/pub/crewdson/misc.html',
#   '/pub/atomicbk/promo/cp93.html',
#   '/pub/emma/html/references.html',
#   '/pub/cargui/country.html',
#   '/pub/jellybn/3427.html',
#   '/pub/howie/OO/about_oo.html',
#   '/pub/downin/html/arlonet/interview.html',
#   '/pub/ghoti/glil/The.Quill.1994/quill942.html',
#   '/pub/fractal/poetry.html',
#   '/pub/rjamesd/HTMLtalk.html',
#   '/pub/czech/consult1.html',
#   '/pub/ahasuer/heinlein/biography.html',
#   '/pub/network/welcome.html',
#   '/pub/wrmi/202bri.htm',
#   '/pub/lschank/web/women.html'],
#  ['/pub/russadam/textsch/barglos1.html',
#   '/pub/marcm52/joshpage.htm',
#   '/pub/lawrencc/info.html',
#   '/pub/lori/books.html',
#   '/pub/murple/local/head-explode.html',
#   '/pub/s-gray/feminist.html',
#   '/pub/jeffd/feedback.html',
#   '/pub/srp/home.html',
#   '/pub/lupine/www/pollard.html',
#   '/pub/lazarus/citadel/cithome.htm',
#   '/pub/networx/fusion.html',
#   '/pub/wil/html/',
#   '/pub/micros/forbes/bo-38.html',
#   '/pub/brendan/home.html',
#   '/pub/heroes/home.html',
#   '/pub/rackets/LT/LTHorsmanBox.html',
#   '/pub/scheyer/dpo_t.htm',
#   '/pub/thedave/family.html',
#   '/pub/lschank/web/govdoc.html',
#   '/pub/rmharris/alldlrs/ma/19720oak.html',
#   '/pub/lupine/www/tlk/changes.html',
#   '/pub/phil/julianahatfield.html',
#   '/pub/rmharris/newsltr/3-01.html',
#   '/pub/jvasquez/home.html',
#   '/pub/faisal/quotes.html',
#   '/pub/mbrophy/new_sandra_page.html',
#   '/pub/lupine/www/madison.html',
#   '/pub/russadam/barcode1.html',
#   '/pub/kiaman/lyingcow.html',
#   '/pub/ghoti/INDEX.html',
#   '/pub/elrod/index.html',
#   '/pub/lschank/web/classics.html',
#   '/pub/gemini/home.html',
#   '/pub/jeffd/lastupd.html',
#   '/pub/alex_b/forum95.html',
#   '/pub/fractal/fractal.html',
#   '/pub/jleitess/james.html',
#   '/pub/epchurch/dale.htm',
#   '/pub/mnoll/wwwr.html',
#   '/pub/ahasuer/pulp/alt.pulp.html',
#   '/pub/global/intell.html',
#   '/pub/lovegrov/retina.html',
#   '/pub/teallen/eps/rf_sampl.html',
#   '/pub/global/wash.html',
#   '/pub/jumpsam/gospain.htm',
#   '/pub/sgs/ubwho.htm',
#   '/pub/TMC/links.html',
#   '/pub/k2/am4x44u/whats_new/camelt20.htm',
#   '/pub/micros/rmi/flag.html',
#   '/pub/rudey/home.html',
#   '/pub/pgarrett/pose.html',
#   '/pub/micros/mr/asia-pac.html',
#   '/pub/k2/am4x44u/events/clubs/club_list.htm',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/reichera/rcp.html',
#   '/pub/mikebilt/gaydc.html',
#   '/pub/grinch/Favorite.html',
#   '/pub/global/patents.html',
#   '/pub/listserv/lstech1b.html',
#   '/pub/cybersoft/zipcode.md.html',
#   '/pub/ghoti/glil/The.Quill.1993/INDEX_text.html',
#   '/pub/jellybn/4796.html',
#   '/pub/chivato/Zero.html',
#   '/pub/lschank/best/bills.html',
#   '/pub/jridgely/dc/union.html',
#   '/pub/ahasuer/heinlein/juveniles.html',
#   '/pub/wrmi/404chn.htm',
#   '/pub/cme/html/l-indexes.html',
#   '/pub/rt/fanpages.html',
#   '/pub/k2/am4x44u/whats_new/4wa6.htm'],
#  ['/pub/jeffd/mr_newt.html', '/pub/jeffd/index.html'],
#  ['/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/manu.html',
#   '/pub/networx/networx.html',
#   '/pub/networx/autopage/classic.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/job/vk/vendela.html',
#   '/pub/jeffd/rushpage.html',
#   '/pub/jeffd/final.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newjul15.html',
#   '/atomicbk/catalog/catalog.html'],
#  ['/pub/atomicbk/catalog/adultcom.html',
#   '/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/classic.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/pub/networx/networx.html',
#   '/pub/networx/autopage/misc.html',
#   '/pub/atomicbk/home.html',
#   '/atomicbk/images/gallery.html',
#   '/pub/rsjdfg/Pictures.html',
#   '/pub/rsjdfg/ActI.html',
#   '/pub/rsjdfg/Life.html',
#   '/pub/rsjdfg/SunMoon.html',
#   '/pub/rsjdfg/Actors.html',
#   '/atomicbk/catalog/catalog.html',
#   '/pub/rsjdfg/Ellen.html',
#   '/pub/rsjdfg/Misty.Cotton.html',
#   '/pub/rsjdfg/The.Engineer.html',
#   '/pub/rsjdfg/Kevin.Gray.html',
#   '/atomicbk/catalog/adultcom.html'],
#  ['/pub/wick/photos.html', '/pub/wick/hell.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/sleazbk.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/erotica.html'],
#  ['/pub/usenet-b/www/home.html',
#   '/pub/jteuber/nnflhome.htm',
#   '/pub/jteuber/nnflhome.htm',
#   '/pub/jteuber/nnflmail.htm'],
#  ['/pub/mmathai/mls/prizes.html', '/pub/mmathai/mls/dcmls.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/robert/current.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/catalog.html'],
#  ['/pub/mikebilt/gaydc.html', '/pub/journalism/awesome.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/lupine/www/tlk/sources.html'],
#  ['/pub/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/pinup.html',
#   '/atomicbk/catalog/catalog.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/wmcbrine/html/', '/pub/wmcbrine/html/Madonna.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/html/usage/usage.graph.small.gif',
#   '/html/clarknet.html',
#   '/html/clarknet.html',
#   '/home.html',
#   '/home1.html',
#   '/html/people.html'],
#  ['/html/people.html',
#   '/html/services.html',
#   '/html/resources.html',
#   '/printing/GOODIES.html',
#   '/printing/IMAGES.html'],
#  ['/pub/sshay/home.html', '/pub/sshay/gallery.html'],
#  ['/pub/listserv/lsmus1.html'],
#  ['/pub/job/vk/vendela.html', '/pub/job/swim/swim.html'],
#  ['/pub/alweiner/cgi-bin/homepage.html?game',
#   '/pub/alweiner/cgi-bin/homepage.html?game+5',
#   '/pub/alweiner/cgi-bin/homepage.html?game+7',
#   '/pub/alweiner/cgi-bin/homepage.html?game+0',
#   '/pub/alweiner/cgi-bin/homepage.html?game+11'],
#  ['/pub/alweiner/cgi-bin/homepage.html?homep0',
#   '/pub/alweiner/cgi-bin/homepage.html?cool-log'],
#  ['/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test',
#   '/pub/alweiner/cgi-bin/homepage.html?test'],
#  ['/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html',
#   '/pub/alweiner/cgi-bin/homepage.html',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2'],
#  ['/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2'],
#  ['/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-register',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login',
#   '/pub/alweiner/cgi-bin/homepage.html',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-register',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login2',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-login1',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-register',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-register',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-register',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-register',
#   '/pub/alweiner/cgi-bin/homepage.html?beta-register'],
#  ['/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/pinup.html'],
#  ['/pub/tile/home.html'],
#  ['/pub/sshay/gallery.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/verbwork.html',
#   '/pub/sshay/chris.html',
#   '/pub/journalism/awesome.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/journalism/awesome.html',
#   '/pub/mikebilt/gaydc.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/mikebilt/gaydc.html',
#   '/pub/journalism/awesome.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/job/swim/swim.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/mikebilt/gaydc.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/muddy/home.html',
#   '/pub/journalism/awesome.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/job/swim/swim.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/kid.html'],
#  ['/pub/lcooksey/home.html'],
#  ['/pub/wmcbrine/html/Maverick.html',
#   '/pub/wmcbrine/html/maverick.gif',
#   '/pub/wmcbrine/html/Icon.html',
#   '/pub/wmcbrine/html/icon5.gif',
#   '/pub/wmcbrine/html/eyes.gif'],
#  ['/pub/journalism/kid.html'],
#  ['/pub/sshay/home.html',
#   '/pub/sshay/interact.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/chris.html'],
#  ['/pub/journalism/kid.html'],
#  ['/pub/sshay/gallery.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/sshay/about.html', '/pub/sshay/chris.html', '/pub/sshay/gallery.html'],
#  ['/pub/sshay/about.html', '/pub/sshay/gallery.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html', '/pub/journalism/awesome.html'],
#  ['/pub/jeffd/index.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/atomicbk/catalog/adultcom.html',
#   '/pub/jeffd/mr_newt.html',
#   '/pub/jeffd/index.html'],
#  ['/pub/journalism/awesome.html', '/pub/jeffd/demockracy.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/indigo/me_boots.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/journalism/awesome.html',
#   '/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/classic.html',
#   '/pub/networx/autopage/classic/cl003.html',
#   '/pub/networx/autopage/dealers.html',
#   '/pub/networx/autopage/articles.html',
#   '/pub/job/swim/swim.html'],
#  ['/pub/job/swim/swim.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/murple/html/drugs.html'],
#  ['/pub/gen/mlg/house.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/atomicbk/new/new.html', '/atomicbk/new/newaug25.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/pub/ibos/home.html',
#   '/pub/ibos/busops.html',
#   '/pub/murple/html/drugs.html',
#   '/pub/murple/home.html',
#   '/pub/murple/html/sex.html',
#   '/pub/murple/html/pages.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/journalism/awesome.html',
#   '/pub/mikebilt/gaydc.html'],
#  ['/pub/lschank/web/educate.html',
#   '/pub/lschank/web/educate.html',
#   '/pub/lschank/web/educate.html',
#   '/pub/lschank/web/educate.html',
#   '/pub/lschank/web/k-12.html',
#   '/pub/lschank/web/k-12.html',
#   '/pub/lschank/web/k-12.html',
#   '/pub/lschank/web/k-12.html',
#   '/pub/phil/home.html',
#   '/pub/phil/ToriAmos.html',
#   '/pub/murple/html/propaganda.html',
#   '/pub/murple/html/pnazi.html'],
#  ['/pub/k2/am4x44u/truck_stop/truck_stop.htm',
#   '/pub/k2/am4x44u/truck_stop/parts/parts.htm'],
#  ['/pub/quaker/web/archive.html'],
#  ['/pub/jeffd/keyes_96.html', '/pub/jgbustam/paises/cuba.html'],
#  ['/pub/robert/current.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/pinup.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/classic.html',
#   '/pub/networx/autopage/classic/cl003.html',
#   '/pub/ibos/home.html',
#   '/pub/journalism/awesome.html',
#   '/pub/lupine/www/lionking.html',
#   '/pub/lupine/www/tlk/cast.html'],
#  ['/pub/murple/html/drugs.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/exotic.html',
#   '/pub/networx/autopage/advertise.html',
#   '/pub/networx/autopage/exotic/ex001.html',
#   '/pub/networx/autopage/exotic/ex002.html',
#   '/pub/networx/autopage/exotic/ex002p.html',
#   '/pub/networx/autopage/exotic/ex003.html',
#   '/pub/networx/autopage/exotic/ex002a.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/jeffd/index.html',
#   '/pub/jeffd/mr_newt.html',
#   '/pub/jeffd/rushpage.html',
#   '/pub/jeffd/rel_left.html',
#   '/pub/jeffd/final.html'],
#  ['/pub/sshay/gallery.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/links.html',
#   '/pub/sshay/chris.html',
#   '/pub/phil/WinonaRyder.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/networx/autopage/autopage.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/job/swim/swim.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/sshay/home.html',
#   '/pub/sshay/about.html',
#   '/pub/sshay/chris.html',
#   '/pub/sshay/gallery.html',
#   '/pub/sshay/interact.html',
#   '/pub/murple/html/drugs.html',
#   '/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/wick/req.html',
#   '/pub/wick/personal.html',
#   '/pub/wick/index.html',
#   '/pub/wick/photos.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/new/newjul15.html', '/pub/atomicbk/contest/contest.html'],
#  ['/html/usage/usage.graph.small.gif',
#   '/html/motd.txt',
#   '/pub/rjamesd/holycros.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/rjk/home.html'],
#  ['/pub/lschank/web/classics.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/verbwork.html',
#   '/pub/journalism/publish.html',
#   '/pub/journalism/scoop.html',
#   '/pub/journalism/brochure.html',
#   '/pub/sshay/gallery.html',
#   '/pub/sshay/links.html',
#   '/pub/sshay/chris.html',
#   '/pub/cargui/scavengr.html',
#   '/pub/jeffd/index.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/verbwork.html',
#   '/pub/keating/ri-hs.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html', '/pub/pribut/spsport.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/jeffd/index.html',
#   '/pub/jeffd/cgi-bin/home.html',
#   '/pub/jeffd/stat-http.html',
#   '/pub/jeffd/comments/bbs.html',
#   '/pub/jeffd/cgi-bin/dodger.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/journalism/verbwork.html',
#   '/pub/journalism/busncard.html',
#   '/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/robert/listserv.html'],
#  ['/pub/jeffd/rushpage.html', '/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/networx/autopage/autopage.html'],
#  ['/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/iz/Books/books.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/books.html'],
#  ['/pub/k2/suv/suv.htm',
#   '/pub/k2/suv/suvindex.htm',
#   '/pub/k2/suv/suv2.htm',
#   '/pub/k2/suv/suvindex.htm',
#   '/pub/k2/suv/suv2.htm'],
#  ['/pub/valentin/www/movies01.html',
#   '/pub/valentin/www/movies01.html',
#   '/pub/valentin/www/movies01.html'],
#  ['/pub/tblake/www/friends.html',
#   '/pub/tblake/www/index.html',
#   '/pub/tblake/www/testing.html'],
#  ['/pub/murphy/info.html',
#   '/pub/murphy/home.html',
#   '/pub/murphy/events.html',
#   '/pub/murphy/art.html',
#   '/nbp/index.html',
#   '/pub/kolesar/home.html',
#   '/pub/murphy/legend.html',
#   '/pub/murphy/home.html',
#   '/pub/murphy/info.html',
#   '/pub/murphy/events.html'],
#  ['/pub/kolesar/home.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/kolesar/home.html'],
#  ['/html/usage/usage.graph.small.gif'],
#  ['/html/usage/usage.graph.small.gif'],
#  ['/html/usage/usage.graph.small.gif'],
#  ['/pub/corrigan/places.html',
#   '/pub/corrigan/places.html',
#   '/pub/mpowers/j4j/web/j4jmission.html',
#   '/pub/mpowers/j4j/web/j4joffices.html',
#   '/pub/mpowers/j4j/web/j4jbaltmail.html',
#   '/pub/mpowers/j4j/web/j4jsuemail.html'],
#  ['/html/usage/usage.graph.small.gif',
#   '/pub/reichera/fun.html',
#   '/pub/job/home.html?199,175',
#   '/pub/job/mpegs/util.html'],
#  ['/html/usage/usage.graph.small.gif'],
#  ['/pub/reichera/rcp.html', '/html/faq.html'],
#  ['/pub/reichera/rcp.html',
#   '/pub/jkeene/home.html',
#   '/pub/jkeene/jkref.htm',
#   '/pub/jkeene/jkrdng.htm',
#   '/pub/pjs/linux.html',
#   '/pub/pjs/brew.html'],
#  ['/pub/lwallach/nyfoods1.html',
#   '/pub/lwallach/nyfoods2.html',
#   '/pub/lwallach/nyfoods3.html',
#   '/bpinews/content/swr08245.htm',
#   '/bpinews/content/swr08245.htm',
#   '/bpinews/content/ert08235.htm',
#   '/bpinews/archive/ert08235.htm',
#   '/bpinews/cgi-bin/mailout?bpinews@clark.net+http://www.clark.net/bpinews/archive/ert08235.htm',
#   '/bpinews/archive/ert08235.htm',
#   '/bpinews/archive/ert08235.htm',
#   '/bpinews/index.htm',
#   '/bpinews/cgi-bin/mailout?bpinews@clark.net+http://www.clark.net/bpinews/archive/ert08235.htm',
#   '/html/usage/usage.graph.small.gif',
#   '/bpinews/content/nwn08175.htm',
#   '/bpinews/content/nwn08175.htm',
#   '/pub/bdalzell/home.html',
#   '/pub/bdalzell/wolf/wolfpark.html',
#   '/html/usage/usage.graph.small.gif',
#   '/html/link.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/madsox/home.html'],
#  ['/pub/madsox/home.html',
#   '/pub/madsox/home.html',
#   '/pub/madsox/home.html',
#   '/pub/madsox/home.html'],
#  ['/pub/peace/MI1.html',
#   '/pub/peace/MI2.html',
#   '/pub/peace/VRS2.html',
#   '/pub/peace/VRS4.html',
#   '/pub/peace/VRS7.html',
#   '/pub/peace/Country1.html',
#   '/pub/peace/AP.html',
#   '/pub/peace/Address1.html',
#   '/pub/peace/Africa.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/sshay/home.html', '/pub/sshay/gallery.html'],
#  ['/pub/jeffd/index.html',
#   '/pub/jeffd/liealot.html',
#   '/pub/jeffd/cgi-bin/home.html'],
#  ['/pub/sshay/gallery.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/links.html'],
#  ['/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html'],
#  ['/pub/rjgula/network.htm',
#   '/pub/rjgula/attacks.htm',
#   '/pub/rjgula/os.htm',
#   '/pub/rjgula/faqs.htm'],
#  ['/pub/robert/current.html'],
#  ['/pub/k2/am4x44u/4x4.html'],
#  ['/pub/phil/WinonaRyder/articles/Life.Jun89.html'],
#  ['/pub/atomicbk/huffines.html'],
#  ['/pub/sshay/about.html',
#   '/pub/sshay/interact.html',
#   '/pub/sshay/chris.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/gallery.html'],
#  ['/pub/pgarrett/pose.html',
#   '/pub/sshay/gallery.html',
#   '/pub/sshay/chris.html',
#   '/pub/sshay/partner.html'],
#  ['/pub/ibos/contempo/jewelry1.html'],
#  ['/pub/cargui/photos.html'],
#  ['/pub/farm/emma.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/mbrophy/the_sandra_page.html'],
#  ['/pub/atomicbk/catalog/pinup.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/sshay/home.html'],
#  ['/pub/sshay/about.html', '/pub/sshay/about.html'],
#  ['/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/Books/books.html'],
#  ['/pub/iz/Books/books.html', '/pub/iz/Books/books.html'],
#  ['/pub/wick/hell.html'],
#  ['/pub/ibos/coffee/coffee.html'],
#  ['/pub/terra/nba.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/phil/WinonaRyder.html', '/pub/phil/WinonaRyder.html'],
#  ['/pub/jeffd/keyes_at.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/pub/robert/current.html',
#   '/pub/indigo/new.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/tara/index.html',
#   '/tara/catalog.htm',
#   '/tara/catbooks.htm'],
#  ['/pub/journalism/awesome.html', '/pub/journalism/awesome.html'],
#  ['/pub/fractal/resexp.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newaug25.html',
#   '/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/job/vk/vendela.html', '/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/classic.html',
#   '/pub/networx/autopage/exotic.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/lschank/web/geo.html'],
#  ['/pub/jeffd/index.html', '/pub/jeffd/comments/bbs.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/robert/current.html'],
#  ['/pub/mbrophy/the_sandra_page.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/lschank/web/govdoc.html',
#   '/pub/phil/WinonaRyder.html',
#   '/pub/journalism/awesome.html'],
#  ['/html/usage/usage.graph.small.gif', '/pub/journalism/awesome.html'],
#  ['/pub/job/vk/vendela.html',
#   '/pub/job/swim/swim.html',
#   '/pub/job/swim/swim.html'],
#  ['/pub/atomicbk/catalog/death.html'],
#  ['/pub/k2/am4x44u/4x4.html',
#   '/pub/k2/am4x44u/truck_stop/truck_stop.htm',
#   '/pub/k2/am4x44u/truck_stop/catalogs/catalogs.htm',
#   '/pub/k2/am4x44u/truck_stop/links/links.htm',
#   '/pub/k2/am4x44u/whats_new/cool_stuff.htm',
#   '/pub/k2/am4x44u/whats_new/links.htm',
#   '/pub/k2/am4x44u/whats_new/links.htm'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/mikebilt/gaydc.html'],
#  ['/pub/k2/am4x44u/video/cjhp.htm',
#   '/pub/journalism/awesome.html',
#   '/pub/k2/am4x44u/video/cjmodel.htm',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/sshay/gallery.html',
#   '/pub/ibos/busops.html',
#   '/pub/ibos/moto/home.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/global/maps.html',
#   '/pub/wick/photos.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/atomicbk/home.html',
#   '/pub/pgarrett/pose.html',
#   '/pub/stc/www/board.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/atomicbk/catalog/adultcom.html', '/atomicbk/new/new.html'],
#  ['/pub/job/vk/vendela.html', '/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/mmathai/mls/washpost.html', '/pub/mmathai/mls/index.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/terra/nba.html',
#   '/pub/craver/surreal/surreal.html',
#   '/pub/craver/surreal/opener.htm',
#   '/pub/craver/surreal/SPHP.htm',
#   '/pub/craver/surreal/surround.htm',
#   '/pub/craver/surreal/billgrey.htm',
#   '/pub/craver/surreal/fall.htm'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/catalog.html',
#   '/pub/jwolff/cki.html',
#   '/atomicbk/catalog/sleazmag.html',
#   '/atomicbk/new/new.html'],
#  ['/pub/usenet-b/www/home.html',
#   '/pub/jeffd/index.html',
#   '/pub/jeffd/96centrl.html',
#   '/pub/jeffd/keyes_96.html',
#   '/pub/jeffd/96yes.html',
#   '/khem/home.html',
#   '/pub/mbrophy/the_sandra_page.html',
#   '/pub/mbrophy/sandras_home.html',
#   '/pub/mbrophy/the_scoop.html',
#   '/pub/mbrophy/interviews.html',
#   '/pub/mbrophy/other_sites.html',
#   '/pub/sshay/gallery.html',
#   '/pub/journalism/awesome.html',
#   '/pub/sshay/chris.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html',
#   '/pub/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/shocked.html',
#   '/pub/atomicbk/home.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/listserv/listserv.html'],
#  ['/pub/jeffd/mr_newt.html'],
#  ['/pub/wick/req.html',
#   '/pub/wick/index.html',
#   '/pub/wick/photos.html',
#   '/pub/wick/otherpages.html',
#   '/pub/wick/other_cool.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/wimmens.html',
#   '/atomicbk/catalog/sleazmag.html',
#   '/atomicbk/catalog/erotica.html'],
#  ['/pub/cardman/poll.htm',
#   '/pub/cardman/fball.htm',
#   '/pub/cardman/terms.htm',
#   '/pub/cardman/tbasket.htm'],
#  ['/pub/cardman/curious.htm', '/pub/cardman/links.htm'],
#  ['/pub/cardman/deals.htm'],
#  ['/pub/csamsi/html/wsirc.gif'],
#  ['/pub/csamsi/html/wsirc.gif'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/theme/factinfo.html'],
#  ['/pub/robert/current.html'],
#  ['/pub/pribut/chess.html',
#   '/pub/listserv/lshist1.html',
#   '/pub/journalism/awesome.html',
#   '/pub/murple/html/weird.html',
#   '/pub/jeffd/final.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/murple/html/drugs.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/html/usage/usage.graph.small.gif',
#   '/html/clarknet.html',
#   '/html/services.html',
#   '/pub/journalism/iaptable.html'],
#  ['/pub/sshay/home.html',
#   '/pub/sshay/gallery.html',
#   '/pub/sshay/links.html',
#   '/pub/sshay/chris.html'],
#  ['/pub/mikebilt/gaydc.html'],
#  ['/pub/jeffd/mr_newt.html',
#   '/larouche/welcome.html',
#   '/pub/jeffd/index.html',
#   '/larouche/Quacks.html'],
#  ['/pub/jeffd/rushpage.html'],
#  ['/pub/edseiler/WWW/jenkins/Asimov.html',
#   '/pub/edseiler/WWW/jenkins/Alphabetical.html',
#   '/pub/edseiler/WWW/jenkins/Reviews/020.html',
#   '/pub/edseiler/WWW/jenkins/Reviews/011.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/lschank/web/country.html',
#   '/pub/lschank/web/foreign.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/atomicbk/images/gallery.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/k2/am4x44u/4x4.html',
#   '/pub/k2/am4x44u/trails/land_parks/land_parks.htm',
#   '/pub/k2/am4x44u/truck_tech/4x_trucks/4x_trucks.htm'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/global/subjectlist.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/peace/PeaceCorps.html'],
#  ['/pub/listserv/dir1.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/k2/am4x44u/4x4.html'],
#  ['/pub/lschank/web/educate.html', '/pub/lschank/web/k-12.html'],
#  ['/pub/wick/photos.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html', '/atomicbk/images/gallery.html'],
#  ['/pub/atomicbk/catalog/pinup.html',
#   '/pub/atomicbk/catalog/pinup.html',
#   '/pub/atomicbk/catalog/pinup.html'],
#  ['/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/erotica.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/phil/WinonaRyder.html'],
#  ['/pub/k2/jeep/jeep.htm',
#   '/pub/k2/jeep/jeep2.htm',
#   '/pub/k2/jeep/jparts.htm',
#   '/pub/k2/am4x44u/video/arbpage2.htm',
#   '/pub/k2/am4x44u/truck_stop/ametal.htm',
#   '/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/atomicbk/new/newjul15.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newaug04.html',
#   '/pub/atomicbk/new/new.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/wimmens.html',
#   '/pub/journalism/awesome.html',
#   '/pub/atomicbk/catalog/erotica.html',
#   '/nrlc/form.html',
#   '/nrlc/pba.html',
#   '/nrlc/pbamis.html',
#   '/nrlc/index.html'],
#  ['/pub/lschank/web/gov.html', '/pub/journalism/awesome.html'],
#  ['/pub/murple/html/drugs.html'],
#  ['/pub/murple/html/propaganda.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/robert/home.html', '/pub/robert/current.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/usenet-b/www/home.html', '/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/k2/am4x44u/4x4.html',
#   '/pub/k2/am4x44u/4x4.html',
#   '/pub/lschank/web/behave.html',
#   '/pub/diplonet/DiploNet.html',
#   '/pub/diplonet/WIN_Group.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html', '/pub/phil/WinonaRyder.html'],
#  ['/pub/russadam/barcode1.html'],
#  ['/pub/journalism/awesome.html', '/pub/journalism/awesome.html'],
#  ['/pub/fbc/www/disks.html'],
#  ['/pub/madsox/fmashort.html',
#   '/pub/lschank/web/country.html',
#   '/pub/sgs/ubm1289.htm',
#   '/pub/lschank/web/educate.html',
#   '/pub/sgs/ubprofil.htm',
#   '/pub/jeffd/index.html',
#   '/pub/jeffd/cgi-bin/ngquote.html',
#   '/pub/journalism/awesome.html',
#   '/pub/jeffd/rushpage.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/ibos/company/question.html'],
#  ['/pub/wine/home.html',
#   '/pub/wine/advocate.html',
#   '/pub/wine/main.html',
#   '/pub/wine/fav.html',
#   '/pub/wine/fall94.html',
#   '/pub/wine/pauillac.html'],
#  ['/pub/chivato/evolution.html'],
#  ['/pub/cargui/links.html'],
#  ['/pub/temonk/heavwww.htm'],
#  ['/pub/czech/czechslv.html', '/pub/czech/czechss.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/sshay/home.html', '/pub/sshay/partner.html', '/pub/wick/photos.html'],
#  ['/pub/rmharris/booknet1.html', '/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/mikebilt/gaydc.html', '/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/pub/mmathai/mls/dcmls.html',
#   '/pub/mmathai/mls/mlsteams.html',
#   '/pub/mmathai/mls/washpost.html'],
#  ['/pub/wmcbrine/html/Madonna.html'],
#  ['/pub/atomicbk/huffines.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/epchurch/flanagan.htm',
#   '/pub/epchurch/home.html',
#   '/html/faq.html',
#   '/home.html',
#   '/home1.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/mmathai/mls/dcmls.html',
#   '/pub/mmathai/mls/washpost.html',
#   '/pub/mmathai/mls/prizes.html',
#   '/pub/mmathai/mls/dctour.html'],
#  ['/pub/mmathai/mls/mlsteams.html',
#   '/pub/pgarrett/pose.html',
#   '/pub/job/vk/vendela.html',
#   '/pub/job/swim/swim.html'],
#  ['/pub/boscomel/xfiles.html'],
#  ['/pub/sshay/about.html'],
#  ['/pub/journalism/awesome.html', '/pub/job/vk/vendela.html'],
#  ['/pub/listserv/listserv.html',
#   '/pub/listserv/lsvl1.html',
#   '/pub/listserv/lsmed1.html',
#   '/pub/listserv/lsti1.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/sleazmag.html',
#   '/atomicbk/catalog/erotica.html'],
#  ['/pub/jeffd/mr_newt.html',
#   '/pub/jeffd/cgi-bin/ngquote.html',
#   '/pub/jeffd/cgi-bin/ngquote.html',
#   '/pub/jeffd/cgi-bin/ngquote.html',
#   '/rtside/comments/bbs.html'],
#  ['/pub/rmharris/catalogs/parmecat/intro.html',
# ...
#  ['/pub/lupine/www/other-disney.html'],
#  ['/atomicbk/images/gallery.html', '/pub/atomicbk/huffines.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/atomicbk/home.html',
#   '/atomicbk/shocked.html',
#   '/atomicbk/userlink.html'],
#  ['/pub/lschank/home.html'],
#  ['/pub/lschank/web/foreign.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/home.html',
#   '/atomicbk/shocked.html',
#   '/pub/atomicbk/orderform.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/sleazbk.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/atomicbk/catalog/pinup.html'],
#  ['/pub/rjgula/attacks.htm'],
#  ['/pub/rjgula/faqs.htm', '/pub/rjgula/os.htm'],
#  ['/pub/atomicbk/catalog/pinup.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/winfield/brian.html'],
#  ['/pub/mileskb/boc/boc.html',
#   '/pub/mileskb/boc/news.html',
#   '/pub/mileskb/boc/more.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/capital/home.html'],
#  ['/pub/mbrophy/the_sandra_page.html', '/pub/mbrophy/sandras_home.html'],
#  ['/pub/ibos/busops.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/peace/PeaceCorps.html',
#   '/pub/peace/Country1.html',
#   '/pub/peace/Africa.html',
#   '/pub/peace/EACAM.html',
#   '/pub/peace/AP.html',
#   '/pub/peace/IA.html'],
#  ['/pub/rjamesd/jda.html', '/pub/rjamesd/jda.html'],
#  ['/pub/micros/rmi/index.html', '/pub/jeffd/index.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/atomicbk/catalog/pinup.html',
#   '/pub/atomicbk/catalog/sleazmag.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/adultcom.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/catalog/sleazmag.html',
#   '/pub/job/vk/vendela.html',
#   '/atomicbk/catalog/zines.html'],
#  ['/pub/job/vk/vendela.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/pub/phil/WinonaRyder.html',
#   '/pub/atomicbk/catalog/adultcom.html',
#   '/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/journalism/awesome.html', '/pub/job/vk/vendela.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/ibos/coffee/coffee.html', '/pub/ibos/busops.html'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newaug25.html'],
#  ['/pub/journalism/awesome.html', '/pub/job/vk/vendela.html'],
#  ['/pub/mikebilt/gaydc.html',
#   '/pub/jeffd/rushpage.html',
#   '/pub/networx/autopage/autopage.html',
#   '/pub/networx/autopage/classic.html'],
#  ['/pub/journalism/awesome.html', '/pub/journalism/verbwork.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/pmls/pmls.html',
#   '/pub/pmls/docs/props.html',
#   '/pub/pmls/docs/pysx0001.html'],
#  ['/rtside/keyes_96.html'],
#  ['/pub/peace/PeaceCorps.html',
#   '/pub/peace/VRS1.html',
#   '/pub/peace/VRS9.html',
#   '/pub/peace/FAQ1.html',
#   '/pub/peace/VRS3.html',
#   '/pub/peace/VRS2.html',
#   '/pub/peace/VRS4.html',
#   '/pub/peace/Touch.html',
#   '/pub/peace/Touch24.html',
#   '/pub/peace/VRS5.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/adultcom.html'],
#  ['/atomicbk/huffines.html',
#   '/atomicbk/huffines.html',
#   '/atomicbk/huffines.html'],
#  ['/pub/journalism/kid.html'],
#  ['/pub/iz/home.html',
#   '/pub/iz/cgi-bin/counter?doc=home.html',
#   '/pub/iz/Jump/jump.html',
#   '/pub/iz/cgi-bin/counter?doc=Jump/jump.html'],
#  ['/pub/jeffd/index.html', '/pub/jeffd/rushpage.html'],
#  ['/pub/job/vk/vendela.html', '/pub/job/vk/vendela.html'],
#  ['/pub/rt/indiehub.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/rackets/TT/TTMiltonBradley.html', '/pub/rackets/takeover.html'],
#  ['/pub/k2/am4x44u/4x4.html'],
#  ['/pub/listserv/lsmus1.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html', '/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/global/front.html',
#   '/pub/global/search.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html', '/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/aztec/mariner/home.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/pwalker/home.html'],
#  ['/pub/royfc/roy1page.html',
#   '/pub/royfc/ru_lingo.html',
#   '/pub/royfc/ru_more.html'],
#  ['/pub/sshay/gallery.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/atomicbk/catalog/pinup.html'],
#  ['/pub/boscomel/boscomel.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/larouche/welcome.html',
#   '/larouche/campaign_info.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/adultcom.html', '/atomicbk/images/gallery.html'],
#  ['/pub/journalism/brochure.html'],
#  ['/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/iz/Books/books.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/books.html'],
#  ['/pub/aztec/capquest/capquest.html',
#   '/pub/aztec/capquest/procapt.html',
#   '/pub/aztec/capquest/mailform.html'],
#  ['/pub/rmharris/abaa.html'],
#  ['/theme/factinfo.html', '/theme/vwfactez.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/spinnaker/home.html'],
#  ['/pub/reichera/pctalk.html'],
#  ['/pub/sshay/about.html',
#   '/pub/sshay/gallery.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/links.html',
#   '/pub/sshay/paul.html'],
#  ['/nbp/nbpcata.html',
#   '/nbp/nbpcata2.html',
#   '/nbp/nbptest.html',
#   '/pub/nbp/nbphome.html'],
#  ['/nbp/nbptest.html'],
#  ['/pub/journalism/kid.html'],
#  ['/pub/wmcbrine/html/Madonna.html',
#   '/pub/wmcbrine/html/Madonna.html',
#   '/pub/wmcbrine/html/Medio-view.html'],
#  ['/pub/wmcbrine/html/Maverick.html', '/pub/wmcbrine/html/maverick.gif'],
#  ['/pub/k2/am4x44u/truck_stop/ametal.htm',
#   '/pub/k2/am4x44u/truck_stop/amrcksld.htm'],
#  ['/pub/sshay/gallery.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/iz/home.html',
#   '/pub/iz/cgi-bin/counter?doc=home.html'],
#  ['/pub/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/adultcom.html'],
#  ['/pub/atomicbk/new/newjul15.html'],
#  ['/pub/jellybn/espfono.html', '/pub/jellybn/5036.html'],
#  ['/pub/listserv/listserv.html', '/pub/listserv/top40.html'],
#  ['/pub/listserv/listserv.html',
#   '/pub/listserv/top40.html',
#   '/pub/listserv/lsvl1.html',
#   '/pub/listserv/lstech1.html',
#   '/pub/listserv/lspc1.html'],
#  ['/pub/listserv/listserv.html',
#   '/pub/listserv/top40.html',
#   '/pub/listserv/wsg.html'],
#  ['/pub/listserv/listserv.html',
#   '/pub/listserv/lsvl1.html',
#   '/pub/listserv/lsmed1.html',
#   '/pub/listserv/wsg.html'],
#  ['/pub/listserv/imag.html',
#   '/pub/listserv/imagfeat.html',
#   '/pub/listserv/imagintr.html',
#   '/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/winfield/brian.html', '/winfield/index.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/mikebilt/gaydc.html', '/pub/mikebilt/gaydc.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/wimmens.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/epchurch/home.html'],
#  ['/pub/lschank/web/educate.html'],
#  ['/pub/terra/nba.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/jrinker/rinker.html',
#   '/pub/jrinker/index.htm',
#   '/pub/jrinker/icons.htm'],
#  ['/pub/atomicbk/catalog/erotica.html',
#   '/atomicbk/commlink.html',
#   '/atomicbk/userlink.html',
#   '/atomicbk/direct.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/erotica.html',
#   '/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/sleazmag.html'],
#  ['/pub/rjgula/network.htm',
#   '/pub/rjgula/attacks.htm',
#   '/pub/rjgula/faqs.htm'],
#  ['/pub/atomicbk/catalog/pinup.html'],
#  ['/pub/sshay/about.html'],
#  ['/pub/sshay/home.html'],
#  ['/larouche/welcome.html',
#   '/ccentral/candidat.htm',
#   '/ccentral/presprim.htm'],
#  ['/pub/jeffd/mr_newt.html',
#   '/pub/jeffd/rushpage.html',
#   '/pub/jeffd/96centrl.html',
#   '/pub/jeffd/96not.html',
#   '/pub/jeffd/96yes.html'],
#  ['/pub/phil/VerucaSalt.html', '/pub/phil/VerucaSalt/RandomNotes.html'],
#  ['/pub/lupine/www/other-disney.html'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/jteuber/nnflhome.htm'],
#  ['/pub/jteuber/nnflhome.htm'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/rjgula/network.htm',
#   '/pub/rjgula/os.htm',
#   '/pub/rjgula/faqs.htm',
#   '/pub/rjgula/attacks.htm',
#   '/pub/rjgula/todo.htm'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/cult.html'],
#  ['/pub/jeffd/cgi-bin/dodger.html'],
#  ['/pub/jeffd/demockracy.html',
#   '/pub/theme/demockracy/today.html',
#   '/pub/theme/demockracy/classic.html'],
#  ['/pub/rmharris/booknet1.html', '/pub/rmharris/catalogs.html'],
#  ['/pub/hutchens/a10.html'],
#  ['/html/usage/usage.graph.small.gif', '/pub/journalism/awesome.html'],
#  ['/pub/robert/current.html'],
#  ['/pub/cardman/whtmarb.jpg',
#   '/pub/cardman/deals.htm',
#   '/pub/cardman/tbasket.htm',
#   '/pub/cardman/rise.htm',
#   '/pub/cardman/class.htm',
#   '/pub/cardman/example.htm',
#   '/pub/cardman/10cards.htm',
#   '/pub/cardman/seattle.htm',
#   '/pub/cardman/ask.htm',
#   '/pub/cardman/hot.htm',
#   '/pub/cardman/links.htm',
#   '/pub/cardman/poll.htm'],
#  ['/pub/atomicbk/catalog/sleazmag.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/csamsi/html/wsirc.gif', '/html/usage/usage.graph.small.gif'],
#  ['/pub/mbrophy/the_sandra_page.html'],
#  ['/pub/atomicbk/catalog/catalog.html'],
#  ['/pub/cme/html/ranno.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/csamsi/html/release.html', '/pub/csamsi/html/wsirc.gif'],
#  ['/pub/mbrophy/the_sandra_page.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/lupine/www/lionking.html', '/pub/k2/jeep/jeep.htm'],
#  ['/pub/k2/jeep/jeep2.htm', '/pub/k2/jeep/jcj.htm', '/pub/k2/jeep/jparts.htm'],
#  ['/pub/k2/am4x44u/4x4.html',
#   '/pub/k2/am4x44u/trails/land_parks/land_parks.htm'],
#  ['/pub/networx/autopage/dealers/de001.html',
#   '/pub/networx/autopage/dealers/de001_1.html',
#   '/pub/networx/autopage/dealers/de001_3.html',
#   '/pub/networx/autopage/dealers/de001_4.html',
#   '/pub/networx/autopage/dealers/de001_a.html',
#   '/pub/networx/autopage/dealers/de001_5.html',
#   '/pub/networx/networx.html',
#   '/pub/networx/autopage/dealers/de001_6.html'],
#  ['/pub/listserv/atom1a.html'],
#  ['/pub/journalism/awesome.html', '/pub/journalism/awesome.html'],
#  ['/pub/k2/am4x44u/4x4.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/terra/nba.html'],
#  ['/pub/k2/jeep/jzj.htm', '/pub/k2/jeep/jyj.htm', '/pub/k2/jeep/jxj.htm'],
#  ['/pub/murple/html/drugs.html'],
#  ['/pub/iz/home.html', '/pub/iz/cgi-bin/counter?doc=home.html'],
#  ['/pub/atomicbk/home.html'],
#  ['/pub/atomicbk/catalog/adultcom.html'],
#  ['/pub/bitbytes/bitbytes.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/sshay/about.html', '/pub/sshay/chris.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/sshay/gallery.html'],
#  ['/pub/ahasuer/heinlein/heinlein.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/s-gray/feminist.html'],
#  ['/pub/phil/JulianaHatfield.html', '/pub/phil/JulianaHatfieldGallery.html'],
#  ['/pub/lupine/www/lionking.html',
#   '/pub/lupine/www/tlk/cast.html',
#   '/pub/lupine/www/tlk/quarto.html',
#   '/pub/lupine/www/tlk/oopsies.html',
#   '/pub/lupine/www/tlk/sources.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/cargui/links.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/rasputin/www/home.html',
#   '/pub/rasputin/www/animate/aniannex.html',
#   '/pub/rasputin/www/sanctum.html'],
#  ['/pub/listserv/lsrel1.html'],
#  ['/pub/atomicbk/catalog/pinup.html'],
#  ['/theme/cgi-bin/serch.html', '/theme/cgi-bin/serchstr.html'],
#  ['/theme/factinfo.html', '/theme/vwfactez.html'],
#  ['/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/lupine/www/disney.html', '/pub/lupine/www/other-disney.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/sshay/gallery.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/atomicbk/catalog/adultcom.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newaug25.html'],
#  ['/pub/sshay/gallery.html', '/pub/sshay/partner.html'],
#  ['/pub/listserv/lsmus1.html'],
#  ['/pub/lupine/www/lionking.html'],
#  ['/pub/temonk/heavwww.htm'],
#  ['/pub/phil/WinonaRyder.html'],
#  ['/pub/ibos/lifeplus/home.html'],
#  ['/pub/sshay/gallery.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/chris.html',
#   '/pub/sshay/about.html'],
#  ['/pub/wick/photos.html'],
#  ['/pub/atomicbk/catalog/adultcom.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/orderform.html'],
#  ['/pub/terra/nba.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/keating/ri-hs.html'],
#  ['/pub/global/search.html'],
#  ['/pub/robert/home.html'],
#  ['/pub/lschank/web/subject.html'],
#  ['/pub/usenet-b/www/home.html'],
#  ['/pub/jeffd/mr_newt.html'],
#  ['/pub/job/vk/vendela.html', '/pub/job/swim/swim.html'],
#  ['/pub/atomicbk/catalog/erotica.html'],
#  ['/pub/lupine/www/other-disney.html', '/pub/lupine/www/other-disney.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html', '/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/nractive/training.html',
#   '/pub/nractive/train1.html',
#   '/pub/nractive/train2.html',
#   '/pub/nractive/train2.html',
#   '/pub/nractive/train3.html'],
#  ['/pub/atomicbk/catalog/pinup.html',
#   '/atomicbk/catalog/catalog.html',
#   '/atomicbk/catalog/tattoo.html'],
#  ['/atomicbk/catalog/catalog.html',
#   '/atomicbk/new/new.html',
#   '/atomicbk/new/newaug04.html'],
#  ['/pub/lschank/web/download.html'],
#  ['/pub/sshay/gallery.html',
#   '/pub/sshay/chris.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/about.html',
#   '/pub/sshay/gallery.html',
#   '/pub/sshay/links.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html'],
#  ['/pub/usenet-b/www/home.html'],
#  ['/pub/iz/Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html',
#   '/pub/iz/cgi-bin/counter?doc=Books/Top100/top100.html'],
#  ['/pub/atomicbk/catalog/sleazbk.html',
#   '/atomicbk/images/gallery.html',
#   '/atomicbk/promo/promo.html'],
#  ['/pub/k2/am4x44u/4x4.html',
#   '/pub/k2/am4x44u/truck_tech/4x_forum/4x_forum.htm',
#   '/pub/k2/am4x44u/truck_tech/4x_forum/4xfask.htm',
#   '/pub/k2/am4x44u/truck_tech/references/references.htm',
#   '/pub/k2/am4x44u/truck_tech/tech_tips/tech_tips.htm',
#   '/pub/k2/am4x44u/truck_tech/tech_tips/tires.htm'],
#  ['/pub/sshay/home.html',
#   '/pub/sshay/chris.html',
#   '/pub/sshay/partner.html',
#   '/pub/sshay/gallery.html'],
#  ['/pub/robert/home.html', '/pub/robert/current.html'],
#  ['/pub/rdavis/rcmk.html'],
#  ['/pub/journalism/awesome.html', '/pub/reichera/pctalk.html'],
#  ['/pub/journalism/awesome.html'],
#  ['/pub/mmathai/mls/dcmls.html',
#   '/pub/mmathai/mls/dcmls.html',
#   '/pub/mmathai/mls/dcmls.html'],
#  ['/pub/indigo/glb.html'],
#  ['/pub/listserv/wsg.html'],
#  ['/pub/rothman/telhome.html',
#   '/pub/rothman/contents.html',
#   '/pub/rothman/update4.html'],
#  ['/pub/arthur/ilfhome.html', '/pub/arthur/faq.html'],
#  ['/pub/global/front.html',
#   '/pub/global/index1.html',
#   '/pub/global/subject.html',
#   '/pub/global/subjectmap.html',
#   '/pub/global/subjectlist.html',
#   '/pub/journalism/awesome.html'],
#  ['/pub/baltsun/archive/archive.html',
#   '/pub/baltsun/demand.html',
#   '/pub/baltsun/forms.html',
#   '/pub/baltsun/demand.html'],
#  ['/pub/jrinker/rinker.html', '/pub/jrinker/index.htm'],
#  ['/pub/job/vk/vendela.html'],
#  ['/pub/rsjdfg/ProTic.html'],
#  ['/pub/jeffd/index.html'],
#  ['/pub/cargui/travel.html'],
#  ...]

# %% [markdown]
# ## Sequential pattern mining
#
# There is no standard library in Python for sequential pattern mining. I have chose to use one implementation of the PrefixSpan algorithm found there: <https://github.com/chuanconggao/PrefixSpan-py>. Unzip the prefixspan archive and move the resulting folder at the same location than your python code. You can now import the PrefixSpan function as follows:
#
#     from prefixspan.api import PrefixSpan
#
#
# We use another dataset for this part of the practical work (`transactrions.tsv`). Load it.

# %%
from prefixspan.api import PrefixSpan
df_sp = pd.read_table("transactions.tsv", sep="\s+")

# %% [markdown]
# Read the documentation of the PrefixSpan implementation and wrap your dataframe to the required input format.

# %%
list_raw_transactions = df_sp.path.tolist()
mapping = {} # str to int 
reverse_mapping ={} # int to str

def build_db_and_mapping(raw) : 
    res = []
    id = 0
    for tx in raw : 
        res.append([])
        temp = tx.split(";")
        for item in temp : 
            if item not in mapping : 
                mapping[item] = id
                reverse_mapping [id] = item
                id += 1
            res[-1].append(mapping[item])
    return res
            
db = build_db_and_mapping(list_raw_transactions)

# %% [markdown]
# Find the top 100 most frequent sequential pattern and display these patterns only if their length is greater or equal than 2.

# %%
ps = PrefixSpan(db)
sp_top = ps.topk(100)

for sp in sp_top : 
    if len(sp[1]) > 1 : 
        print(">".join([reverse_mapping[x] for x in sp[1]]))
# Out:
# Africa>United_Kingdom
# United_States><
# <>United_States
# Achilles_tendon>Ivory
# Achilles>Atlantic_Ocean
# <><><><
# Achilles_tendon>Atlantic_Ocean>Ocean
# Antlion>Hip_hop_music
# Internet>World_Wide_Web>Google
# Art>Mango
# Archbishop_of_Canterbury>United_States
# Aircraft>Internet>Google
# Aircraft>Internet>World_Wide_Web>Google
# Achilles>Black_Sea
# Animal>Bird
# Africa>England
# Atlantic_Ocean>Ocean
# Internet>Google
# Achilles>Ocean
# Aircraft>Google
# World_Wide_Web>Google
# Aircraft>Internet>World_Wide_Web
# Achilles_tendon>Achilles>Ocean
# Fruit>Mango
# Art>Fruit>Mango
# Aluminium_chloride>Bird
# Achilles_tendon>Atlantic_Ocean
# 14th_century>Rainbow
# Art>Fruit
# United_Kingdom>England
# Aluminium_chloride>Bird>Parrot
# Aircraft>Internet
# Bird>Parrot
# Archbishop_of_Canterbury>Vietnam
# Achilles_tendon>Ocean
# Aircraft>World_Wide_Web
# Archbishop_of_Canterbury>England
# Achilles_tendon>Achilles
# Aluminium_chloride>Parrot
# Aircraft>World_Wide_Web>Google
# <><><
# Internet>World_Wide_Web
# <><
