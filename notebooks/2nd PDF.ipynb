# %%
import os
from IPython.display import display, Image

# %%
os.chdir('/Users/sma/Documents/INRAE internship/correspondence/third_document')

# %%
Image('by_product.png')

# %%
Image('produ_haz_corr.png')

# %%
Image('nltk_var_mean_haz.png')

# %%
Image('NLTK_var_mean_NA.png')

# %% [markdown]
# Within the NA set there is a high density of points at [0,0], as well as a positive correlation between mean and variance up to around 0.2 variance and 0.5 mean. This is not apparent in the NA set.

# %%
Image('nltk_var_mean_bisphenola.png')

# %% [markdown]
# ## Other Word Correlations

# %%
Image('corr_extrawords3.png')

# %%
Image('corr_extrawords2.png')

# %%
Image('corr_extrawords1.png')

# %% [markdown]
# ## Product Regressions, with Noun Words as controls, by Post

# %% [markdown]
# # Pattern Sent

# %%
                            OLS Regression Results                            
==============================================================================
Dep. Variable:              sentiment   R-squared:                       0.006
Model:                            OLS   Adj. R-squared:                  0.005
Method:                 Least Squares   F-statistic:                     3.868
Date:                Thu, 29 Jul 2021   Prob (F-statistic):            0.00170
Time:                        13:50:23   Log-Likelihood:                 1440.9
No. Observations:                3105   AIC:                            -2870.
Df Residuals:                    3099   BIC:                            -2834.
Df Model:                           5                                         
Covariance Type:            nonrobust                                         
========================================================================================================
                                           coef    std err          t      P>|t|      [0.025      0.975]
--------------------------------------------------------------------------------------------------------
const                                    0.4938      0.004    119.256      0.000       0.486       0.502
infant formula                           0.0048      0.002      2.173      0.030       0.000       0.009
sterilized vegetable mixed with fish    -0.0136      0.068     -0.199      0.842      -0.147       0.120
fresh fruit puree mildly processed      -0.0113      0.025     -0.455      0.649      -0.060       0.038
infant cereals                           0.0005      0.003      0.155      0.877      -0.006       0.007
other                                    0.0070      0.002      3.801      0.000       0.003       0.011
==============================================================================
Omnibus:                      265.194   Durbin-Watson:                   1.878
Prob(Omnibus):                  0.000   Jarque-Bera (JB):              776.660
Skew:                          -0.449   Prob(JB):                    2.24e-169
Kurtosis:                       5.280   Cond. No.                         48.6
==============================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # NLTK Sentiment

# %%
                           OLS Regression Results                            
==============================================================================
Dep. Variable:     nltk_compound_mean   R-squared:                       0.013
Model:                            OLS   Adj. R-squared:                  0.011
Method:                 Least Squares   F-statistic:                     8.136
Date:                Thu, 29 Jul 2021   Prob (F-statistic):           1.22e-07
Time:                        13:50:26   Log-Likelihood:                 127.50
No. Observations:                3105   AIC:                            -243.0
Df Residuals:                    3099   BIC:                            -206.8
Df Model:                           5                                         
Covariance Type:            nonrobust                                         
========================================================================================================
                                           coef    std err          t      P>|t|      [0.025      0.975]
--------------------------------------------------------------------------------------------------------
const                                    0.1373      0.006     21.715      0.000       0.125       0.150
infant formula                          -0.0110      0.003     -3.282      0.001      -0.018      -0.004
sterilized vegetable mixed with fish    -0.0214      0.104     -0.205      0.837      -0.226       0.183
fresh fruit puree mildly processed       0.0014      0.038      0.036      0.972      -0.073       0.076
infant cereals                           0.0163      0.005      3.349      0.001       0.007       0.026
other                                    0.0022      0.003      0.790      0.430      -0.003       0.008
==============================================================================
Omnibus:                      188.628   Durbin-Watson:                   1.702
Prob(Omnibus):                  0.000   Jarque-Bera (JB):              490.435
Skew:                           0.337   Prob(JB):                    3.19e-107
Kurtosis:                       4.826   Cond. No.                         48.6
==============================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Subjectivity

# %%
                           OLS Regression Results                            
==============================================================================
Dep. Variable:           subjectivity   R-squared:                       0.008
Model:                            OLS   Adj. R-squared:                  0.006
Method:                 Least Squares   F-statistic:                     5.030
Date:                Thu, 29 Jul 2021   Prob (F-statistic):           0.000136
Time:                        13:50:29   Log-Likelihood:                 1015.8
No. Observations:                3105   AIC:                            -2020.
Df Residuals:                    3099   BIC:                            -1983.
Df Model:                           5                                         
Covariance Type:            nonrobust                                         
========================================================================================================
                                           coef    std err          t      P>|t|      [0.025      0.975]
--------------------------------------------------------------------------------------------------------
const                                    0.1210      0.005     25.477      0.000       0.112       0.130
infant formula                           0.0015      0.003      0.587      0.557      -0.003       0.006
sterilized vegetable mixed with fish     0.0982      0.078      1.255      0.209      -0.055       0.252
fresh fruit puree mildly processed      -0.0134      0.029     -0.469      0.639      -0.069       0.043
infant cereals                           0.0058      0.004      1.581      0.114      -0.001       0.013
other                                    0.0076      0.002      3.598      0.000       0.003       0.012
==============================================================================
Omnibus:                      237.662   Durbin-Watson:                   1.831
Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1319.597
Skew:                           0.024   Prob(JB):                    2.84e-287
Kurtosis:                       6.193   Cond. No.                         48.6
==============================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Modality

# %%
                             OLS Regression Results                              
==================================================================================
Dep. Variable:     modality_sentence_mean   R-squared:                       0.004
Model:                                OLS   Adj. R-squared:                  0.003
Method:                     Least Squares   F-statistic:                     2.628
Date:                    Thu, 29 Jul 2021   Prob (F-statistic):             0.0223
Time:                            13:50:31   Log-Likelihood:                 967.17
No. Observations:                    3105   AIC:                            -1922.
Df Residuals:                        3099   BIC:                            -1886.
Df Model:                               5                                         
Covariance Type:                nonrobust                                         
========================================================================================================
                                           coef    std err          t      P>|t|      [0.025      0.975]
--------------------------------------------------------------------------------------------------------
const                                    0.6150      0.005    127.514      0.000       0.606       0.624
infant formula                          -0.0058      0.003     -2.257      0.024      -0.011      -0.001
sterilized vegetable mixed with fish    -0.0291      0.079     -0.366      0.715      -0.185       0.127
fresh fruit puree mildly processed      -0.0079      0.029     -0.271      0.787      -0.065       0.049
infant cereals                           0.0079      0.004      2.122      0.034       0.001       0.015
other                                   -0.0036      0.002     -1.694      0.090      -0.008       0.001
==============================================================================
Omnibus:                      301.286   Durbin-Watson:                   1.762
Prob(Omnibus):                  0.000   Jarque-Bera (JB):              592.966
Skew:                          -0.635   Prob(JB):                    1.73e-129
Kurtosis:                       4.724   Cond. No.                         48.6
==============================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
